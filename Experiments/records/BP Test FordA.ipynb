# %%
import numpy as np
import matplotlib.pyplot as plt
import inspect
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd
import os

# %%
import importlib
import sys
sys.path.append('../')
from Utils.perturbationsnew import RBPIndividual, RBPIndividualNew1, RBPIndividualNew1fast, RBPIndividualNew2, zeroPerturb, noisePerturb, blurPerturb,multisamplebackgroundIdentification
from Utils.models import *
from Utils.data import perturb, generateSynthetic, generateSyntheticPerturbReal,ReadTS

#print(sys.path)

# %% [markdown]
# ## Test important content removal (accuracy decrease)

# %% [markdown]
# ### Load synthetic dataset and train CNN model

# %%
x_train, y_train,x_test_original, y_test_original = ReadTS('FordA')
y_train = np.where(y_train == -1, 0, y_train)
y_test_original = np.where(y_test_original == -1, 0, y_test_original)
#print(x_train.shape)
#print(y_train)

# %%
from sklearn.preprocessing import StandardScaler
def normalize(TS):

    original_shape = TS.shape
    
    TS_2d = TS.reshape(original_shape[0] , original_shape[1])
    
    scaler = StandardScaler()
    
    TS_normalized = scaler.fit_transform(TS_2d)
    
    TS = TS_normalized.reshape(original_shape)
    
    return TS

x_train = normalize(x_train)
x_test_original = normalize(x_test_original)
#print(x_train[1])

# %%
model = make_CNN_model(x_train.shape[1:],num_classes = 2)
trained_model, history = train_CNN_model(model, x_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 2024-12-02 18:33:36.599870: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 90/90 [==============================] - 2s 20ms/step - loss: 0.5629 - sparse_categorical_accuracy: 0.7014 - val_loss: 0.7653 - val_sparse_categorical_accuracy: 0.4743
# Epoch 2/100
# 90/90 [==============================] - 2s 20ms/step - loss: 0.4668 - sparse_categorical_accuracy: 0.7660 - val_loss: 0.7493 - val_sparse_categorical_accuracy: 0.4743
# Epoch 3/100
# 90/90 [==============================] - 2s 22ms/step - loss: 0.4328 - sparse_categorical_accuracy: 0.7868 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.4813
# Epoch 4/100
# 90/90 [==============================] - 2s 20ms/step - loss: 0.4193 - sparse_categorical_accuracy: 0.7872 - val_loss: 0.6467 - val_sparse_categorical_accuracy: 0.5964
# Epoch 5/100
# 90/90 [==============================] - 2s 22ms/step - loss: 0.3985 - sparse_categorical_accuracy: 0.7944 - val_loss: 0.5901 - val_sparse_categorical_accuracy: 0.6824
# Epoch 6/100
# 90/90 [==============================] - 2s 21ms/step - loss: 0.3981 - sparse_categorical_accuracy: 0.8101 - val_loss: 0.8089 - val_sparse_categorical_accuracy: 0.5687
# Epoch 7/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.3978 - sparse_categorical_accuracy: 0.8069 - val_loss: 1.7062 - val_sparse_categorical_accuracy: 0.5257
# Epoch 8/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.3931 - sparse_categorical_accuracy: 0.7986 - val_loss: 0.3912 - val_sparse_categorical_accuracy: 0.8197
# Epoch 9/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.3795 - sparse_categorical_accuracy: 0.8132 - val_loss: 0.5950 - val_sparse_categorical_accuracy: 0.6949
# Epoch 10/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.3780 - sparse_categorical_accuracy: 0.8139 - val_loss: 0.4008 - val_sparse_categorical_accuracy: 0.8017
# Epoch 11/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.3618 - sparse_categorical_accuracy: 0.8281 - val_loss: 0.3817 - val_sparse_categorical_accuracy: 0.8211
# Epoch 12/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.3613 - sparse_categorical_accuracy: 0.8253 - val_loss: 0.4091 - val_sparse_categorical_accuracy: 0.7989
# Epoch 13/100
# 90/90 [==============================] - 2s 22ms/step - loss: 0.3637 - sparse_categorical_accuracy: 0.8212 - val_loss: 1.2207 - val_sparse_categorical_accuracy: 0.6158
# Epoch 14/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.3606 - sparse_categorical_accuracy: 0.8250 - val_loss: 0.4276 - val_sparse_categorical_accuracy: 0.7670
# Epoch 15/100
# 90/90 [==============================] - 2s 22ms/step - loss: 0.3565 - sparse_categorical_accuracy: 0.8309 - val_loss: 0.4792 - val_sparse_categorical_accuracy: 0.7434
# Epoch 16/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.3467 - sparse_categorical_accuracy: 0.8406 - val_loss: 0.4206 - val_sparse_categorical_accuracy: 0.7739
# Epoch 17/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.3438 - sparse_categorical_accuracy: 0.8392 - val_loss: 0.3610 - val_sparse_categorical_accuracy: 0.8433
# Epoch 18/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.3355 - sparse_categorical_accuracy: 0.8469 - val_loss: 0.3409 - val_sparse_categorical_accuracy: 0.8516
# Epoch 19/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.3271 - sparse_categorical_accuracy: 0.8552 - val_loss: 0.3495 - val_sparse_categorical_accuracy: 0.8336
# Epoch 20/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.3330 - sparse_categorical_accuracy: 0.8378 - val_loss: 0.4723 - val_sparse_categorical_accuracy: 0.7309
# Epoch 21/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.3384 - sparse_categorical_accuracy: 0.8427 - val_loss: 0.3363 - val_sparse_categorical_accuracy: 0.8460
# Epoch 22/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.3314 - sparse_categorical_accuracy: 0.8455 - val_loss: 0.4366 - val_sparse_categorical_accuracy: 0.7712
# Epoch 23/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.3142 - sparse_categorical_accuracy: 0.8608 - val_loss: 0.3420 - val_sparse_categorical_accuracy: 0.8350
# Epoch 24/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.3200 - sparse_categorical_accuracy: 0.8493 - val_loss: 0.3214 - val_sparse_categorical_accuracy: 0.8724
# Epoch 25/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.3076 - sparse_categorical_accuracy: 0.8663 - val_loss: 0.3275 - val_sparse_categorical_accuracy: 0.8474
# Epoch 26/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.3024 - sparse_categorical_accuracy: 0.8719 - val_loss: 0.3036 - val_sparse_categorical_accuracy: 0.8807
# Epoch 27/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.3147 - sparse_categorical_accuracy: 0.8642 - val_loss: 0.4186 - val_sparse_categorical_accuracy: 0.7906
# Epoch 28/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.2981 - sparse_categorical_accuracy: 0.8677 - val_loss: 0.2942 - val_sparse_categorical_accuracy: 0.8932
# Epoch 29/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.2909 - sparse_categorical_accuracy: 0.8698 - val_loss: 0.3178 - val_sparse_categorical_accuracy: 0.8890
# Epoch 30/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.2904 - sparse_categorical_accuracy: 0.8743 - val_loss: 0.9134 - val_sparse_categorical_accuracy: 0.6089
# Epoch 31/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.2895 - sparse_categorical_accuracy: 0.8757 - val_loss: 0.2866 - val_sparse_categorical_accuracy: 0.8974
# Epoch 32/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.2811 - sparse_categorical_accuracy: 0.8826 - val_loss: 0.3937 - val_sparse_categorical_accuracy: 0.8294
# Epoch 33/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.2886 - sparse_categorical_accuracy: 0.8774 - val_loss: 0.2744 - val_sparse_categorical_accuracy: 0.9015
# Epoch 34/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.2694 - sparse_categorical_accuracy: 0.8878 - val_loss: 0.3806 - val_sparse_categorical_accuracy: 0.8003
# Epoch 35/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.2690 - sparse_categorical_accuracy: 0.8896 - val_loss: 0.3239 - val_sparse_categorical_accuracy: 0.8641
# Epoch 36/100
# 90/90 [==============================] - 2s 26ms/step - loss: 0.2667 - sparse_categorical_accuracy: 0.8861 - val_loss: 0.2743 - val_sparse_categorical_accuracy: 0.8863
# Epoch 37/100
# 90/90 [==============================] - 2s 26ms/step - loss: 0.2724 - sparse_categorical_accuracy: 0.8771 - val_loss: 0.2849 - val_sparse_categorical_accuracy: 0.8890
# Epoch 38/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.2664 - sparse_categorical_accuracy: 0.8854 - val_loss: 0.3026 - val_sparse_categorical_accuracy: 0.8710
# Epoch 39/100
# 90/90 [==============================] - 2s 26ms/step - loss: 0.2520 - sparse_categorical_accuracy: 0.8983 - val_loss: 0.3043 - val_sparse_categorical_accuracy: 0.8669
# Epoch 40/100
# 90/90 [==============================] - 2s 26ms/step - loss: 0.2551 - sparse_categorical_accuracy: 0.8910 - val_loss: 0.4877 - val_sparse_categorical_accuracy: 0.7587
# Epoch 41/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.2530 - sparse_categorical_accuracy: 0.8948 - val_loss: 0.2694 - val_sparse_categorical_accuracy: 0.8946
# Epoch 42/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.2547 - sparse_categorical_accuracy: 0.8920 - val_loss: 0.2602 - val_sparse_categorical_accuracy: 0.9168
# Epoch 43/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.2414 - sparse_categorical_accuracy: 0.9010 - val_loss: 0.3598 - val_sparse_categorical_accuracy: 0.8558
# Epoch 44/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.2490 - sparse_categorical_accuracy: 0.8958 - val_loss: 1.1251 - val_sparse_categorical_accuracy: 0.5617
# Epoch 45/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.2356 - sparse_categorical_accuracy: 0.9049 - val_loss: 0.3290 - val_sparse_categorical_accuracy: 0.8724
# Epoch 46/100
# 90/90 [==============================] - 2s 22ms/step - loss: 0.2431 - sparse_categorical_accuracy: 0.8997 - val_loss: 0.2863 - val_sparse_categorical_accuracy: 0.8974
# Epoch 47/100
# 90/90 [==============================] - 2s 22ms/step - loss: 0.2338 - sparse_categorical_accuracy: 0.9014 - val_loss: 0.3590 - val_sparse_categorical_accuracy: 0.8488
# Epoch 48/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.2461 - sparse_categorical_accuracy: 0.8934 - val_loss: 0.2699 - val_sparse_categorical_accuracy: 0.8877
# Epoch 49/100
# 90/90 [==============================] - 2s 22ms/step - loss: 0.2400 - sparse_categorical_accuracy: 0.9021 - val_loss: 0.7628 - val_sparse_categorical_accuracy: 0.6865
# Epoch 50/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.2304 - sparse_categorical_accuracy: 0.9000 - val_loss: 0.2858 - val_sparse_categorical_accuracy: 0.8890
# Epoch 51/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.2261 - sparse_categorical_accuracy: 0.9083 - val_loss: 0.7300 - val_sparse_categorical_accuracy: 0.6824
# Epoch 52/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.2165 - sparse_categorical_accuracy: 0.9087 - val_loss: 0.2877 - val_sparse_categorical_accuracy: 0.9015
# Epoch 53/100
# 90/90 [==============================] - 2s 26ms/step - loss: 0.2136 - sparse_categorical_accuracy: 0.9128 - val_loss: 0.3316 - val_sparse_categorical_accuracy: 0.8544
# Epoch 54/100
# 90/90 [==============================] - 2s 26ms/step - loss: 0.2221 - sparse_categorical_accuracy: 0.9080 - val_loss: 0.2755 - val_sparse_categorical_accuracy: 0.8946
# Epoch 55/100
# 90/90 [==============================] - 2s 26ms/step - loss: 0.2055 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2297 - val_sparse_categorical_accuracy: 0.9098
# Epoch 56/100
# 90/90 [==============================] - 2s 26ms/step - loss: 0.2309 - sparse_categorical_accuracy: 0.9003 - val_loss: 1.3116 - val_sparse_categorical_accuracy: 0.6075
# Epoch 57/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.2067 - sparse_categorical_accuracy: 0.9174 - val_loss: 0.2537 - val_sparse_categorical_accuracy: 0.8988
# Epoch 58/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.2204 - sparse_categorical_accuracy: 0.9083 - val_loss: 0.2645 - val_sparse_categorical_accuracy: 0.8863
# Epoch 59/100
# 90/90 [==============================] - 2s 26ms/step - loss: 0.2088 - sparse_categorical_accuracy: 0.9187 - val_loss: 0.2570 - val_sparse_categorical_accuracy: 0.9098
# Epoch 60/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.2029 - sparse_categorical_accuracy: 0.9215 - val_loss: 0.4285 - val_sparse_categorical_accuracy: 0.7822
# Epoch 61/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.2056 - sparse_categorical_accuracy: 0.9191 - val_loss: 0.8207 - val_sparse_categorical_accuracy: 0.6727
# Epoch 62/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.1775 - sparse_categorical_accuracy: 0.9326 - val_loss: 0.3924 - val_sparse_categorical_accuracy: 0.8072
# Epoch 63/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.1843 - sparse_categorical_accuracy: 0.9285 - val_loss: 1.6149 - val_sparse_categorical_accuracy: 0.5520
# Epoch 64/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.1797 - sparse_categorical_accuracy: 0.9323 - val_loss: 0.8017 - val_sparse_categorical_accuracy: 0.6921
# Epoch 65/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.1768 - sparse_categorical_accuracy: 0.9365 - val_loss: 0.1807 - val_sparse_categorical_accuracy: 0.9570
# Epoch 66/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.1639 - sparse_categorical_accuracy: 0.9385 - val_loss: 0.2282 - val_sparse_categorical_accuracy: 0.9112
# Epoch 67/100
# 90/90 [==============================] - 2s 26ms/step - loss: 0.1601 - sparse_categorical_accuracy: 0.9396 - val_loss: 0.1826 - val_sparse_categorical_accuracy: 0.9362
# Epoch 68/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.1476 - sparse_categorical_accuracy: 0.9465 - val_loss: 0.3308 - val_sparse_categorical_accuracy: 0.8447
# Epoch 69/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.1374 - sparse_categorical_accuracy: 0.9528 - val_loss: 0.3754 - val_sparse_categorical_accuracy: 0.8141
# Epoch 70/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.1487 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.3386 - val_sparse_categorical_accuracy: 0.8502
# Epoch 71/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.1315 - sparse_categorical_accuracy: 0.9514 - val_loss: 0.6914 - val_sparse_categorical_accuracy: 0.7032
# Epoch 72/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.1260 - sparse_categorical_accuracy: 0.9583 - val_loss: 0.2582 - val_sparse_categorical_accuracy: 0.8710
# Epoch 73/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.1250 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.4361 - val_sparse_categorical_accuracy: 0.7351
# Epoch 74/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.1310 - sparse_categorical_accuracy: 0.9528 - val_loss: 0.5456 - val_sparse_categorical_accuracy: 0.7601
# Epoch 75/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.1263 - sparse_categorical_accuracy: 0.9566 - val_loss: 0.6683 - val_sparse_categorical_accuracy: 0.7198
# Epoch 76/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.1106 - sparse_categorical_accuracy: 0.9625 - val_loss: 0.3892 - val_sparse_categorical_accuracy: 0.8211
# Epoch 77/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.1265 - sparse_categorical_accuracy: 0.9556 - val_loss: 1.0323 - val_sparse_categorical_accuracy: 0.7198
# Epoch 78/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.1248 - sparse_categorical_accuracy: 0.9559 - val_loss: 0.2582 - val_sparse_categorical_accuracy: 0.8863
# Epoch 79/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.1204 - sparse_categorical_accuracy: 0.9590 - val_loss: 2.9561 - val_sparse_categorical_accuracy: 0.5673
# Epoch 80/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.1133 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.3080 - val_sparse_categorical_accuracy: 0.8530
# Epoch 81/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.1135 - sparse_categorical_accuracy: 0.9604 - val_loss: 5.3071 - val_sparse_categorical_accuracy: 0.5326
# Epoch 82/100
# 90/90 [==============================] - 2s 23ms/step - loss: 0.1147 - sparse_categorical_accuracy: 0.9625 - val_loss: 0.8894 - val_sparse_categorical_accuracy: 0.6963
# Epoch 83/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.1130 - sparse_categorical_accuracy: 0.9576 - val_loss: 0.3417 - val_sparse_categorical_accuracy: 0.8419
# Epoch 84/100
# 90/90 [==============================] - 2s 26ms/step - loss: 0.1050 - sparse_categorical_accuracy: 0.9632 - val_loss: 0.1460 - val_sparse_categorical_accuracy: 0.9542
# Epoch 85/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.1101 - sparse_categorical_accuracy: 0.9601 - val_loss: 0.1407 - val_sparse_categorical_accuracy: 0.9681
# Epoch 86/100
# 90/90 [==============================] - 2s 26ms/step - loss: 0.0994 - sparse_categorical_accuracy: 0.9653 - val_loss: 0.1538 - val_sparse_categorical_accuracy: 0.9542
# Epoch 87/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.1338 - sparse_categorical_accuracy: 0.9503 - val_loss: 0.1778 - val_sparse_categorical_accuracy: 0.9515
# Epoch 88/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.1138 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.4995 - val_sparse_categorical_accuracy: 0.8044
# Epoch 89/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.1104 - sparse_categorical_accuracy: 0.9583 - val_loss: 0.1682 - val_sparse_categorical_accuracy: 0.9390
# Epoch 90/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.1017 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.2251 - val_sparse_categorical_accuracy: 0.8946
# Epoch 91/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.1008 - sparse_categorical_accuracy: 0.9622 - val_loss: 0.2246 - val_sparse_categorical_accuracy: 0.9196
# Epoch 92/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.1023 - sparse_categorical_accuracy: 0.9653 - val_loss: 0.1364 - val_sparse_categorical_accuracy: 0.9612
# Epoch 93/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.1064 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.2219 - val_sparse_categorical_accuracy: 0.9057
# Epoch 94/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.1028 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.1829 - val_sparse_categorical_accuracy: 0.9334
# Epoch 95/100
# 90/90 [==============================] - 2s 26ms/step - loss: 0.1037 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.1327 - val_sparse_categorical_accuracy: 0.9626
# Epoch 96/100
# 90/90 [==============================] - 2s 26ms/step - loss: 0.0980 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.3157 - val_sparse_categorical_accuracy: 0.8419
# Epoch 97/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.0936 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.4925 - val_sparse_categorical_accuracy: 0.7906
# Epoch 98/100
# 90/90 [==============================] - 2s 24ms/step - loss: 0.0951 - sparse_categorical_accuracy: 0.9691 - val_loss: 0.9592 - val_sparse_categorical_accuracy: 0.6921
# Epoch 99/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.0945 - sparse_categorical_accuracy: 0.9649 - val_loss: 0.7526 - val_sparse_categorical_accuracy: 0.7226
# Epoch 100/100
# 90/90 [==============================] - 2s 25ms/step - loss: 0.1082 - sparse_categorical_accuracy: 0.9649 - val_loss: 0.1406 - val_sparse_categorical_accuracy: 0.9542

# %%
test_loss, test_acc = trained_model.evaluate(x_test_original, y_test_original)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1146 - sparse_categorical_accuracy: 0.9621
# Test accuracy 0.9621211886405945
# Test loss 0.11455830931663513

# %%
def l2norm(perturb):
    difference = perturb - x_test_original
    
    squared_difference = np.square(difference)
    
    sum_of_squares = np.sum(squared_difference, axis=1)
    
    l2_norms = np.sqrt(sum_of_squares)
    
    average_l2_norm = np.mean(l2_norms)
    
    #print(average_l2_norm)

    return average_l2_norm


def perturb_predict(strategy,index_0,index_1):
    if strategy =='RBP1fast':
        bg = multisamplebackgroundIdentification(perturb_test_set)
        x_test_pert = np.asarray([perturb(strategy,x,index_0,index_1,bg = bg) for x in perturb_test_set])
        x_test_pert = np.expand_dims(x_test_pert, axis=-1)
        predictions_pert = model.predict(x_test_pert)
        predictions_pert = np.argmax(predictions_pert,axis=1)
    else:
        x_test_pert = np.asarray([perturb(strategy,x,index_0,index_1) for x in perturb_test_set])
        x_test_pert = np.expand_dims(x_test_pert, axis=-1)
        predictions_pert = model.predict(x_test_pert)
        predictions_pert = np.argmax(predictions_pert,axis=1)

    accuracy = accuracy_score(y_test_original, predictions_pert)
    precision = precision_score(y_test_original, predictions_pert, average='weighted')  
    recall = recall_score(y_test_original, predictions_pert, average='weighted')
    f1 = f1_score(y_test_original, predictions_pert, average='weighted')
    l2 = l2norm(x_test_pert)

    # print(strategy)
    # print(accuracy)
    # print(precision)
    # print(recall)
    # print(f1)

    return accuracy,precision,recall,f1,l2

# %%
perturb_test_set = x_test_original.copy()
perturb_test_set = perturb_test_set.reshape(x_test_original.shape[0:2])
index_0 = 30
index_1 = 60

strategies = ['RBP', 'RBP1fast', 'zero', 'noise', 'blur']

results = []
l2_results = []

for strategy in strategies:
    accuracy, precision, recall, f1, l2 = perturb_predict(strategy, index_0, index_1)
    results.append([strategy, accuracy, precision, recall, f1])
    l2_results.append(l2)

columns = ['Strategy', 'Accuracy', 'Precision', 'Recall', 'F1 Score']
df_results = pd.DataFrame(results, columns=columns)
l2_columns = ['L2-Norm']
l2_results = pd.DataFrame(l2_results, columns=l2_columns)

predictions_original = model.predict(x_test_original)
predictions_original = np.argmax(predictions_original,axis=1)
accuracy = accuracy_score(y_test_original, predictions_original)
precision = precision_score(y_test_original, predictions_original, average='weighted')  
recall = recall_score(y_test_original, predictions_original, average='weighted')
f1 = f1_score(y_test_original, predictions_original, average='weighted')
original_data = ['original', accuracy, precision, recall, f1]
df_results.loc[-1] = original_data  
df_results.index = df_results.index + 1  
df_results = df_results.sort_index()  

df_results.loc[2, 'Strategy'] = 'MRBP'

current_directory = os.getcwd()
result_folder = os.path.join(current_directory, 'result_data')

csv_path = os.path.join(result_folder, 'FordB.csv')
df_results.to_csv(csv_path, index=False)

csv_path = os.path.join(result_folder, 'FordBl2.csv')
l2_results.to_csv(csv_path, index=False)

print("done")
print(df_results)
print(l2_results)
# Out:
# 42/42 [==============================] - 0s 4ms/step
# 42/42 [==============================] - 0s 4ms/step
# 42/42 [==============================] - 0s 4ms/step
# 42/42 [==============================] - 0s 4ms/step
# 27/42 [==================>...........] - ETA: 0s
# /Users/gali/anaconda3/envs/LIMEtf/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 42/42 [==============================] - 0s 4ms/step
# 42/42 [==============================] - 0s 4ms/step
# done
#    Strategy  Accuracy  Precision    Recall  F1 Score
# 0  original  0.962121   0.963266  0.962121  0.962128
# 1       RBP  0.907576   0.918851  0.907576  0.906677
# 2      MRBP  0.517424   0.750657  0.517424  0.354531
# 3      zero  0.890909   0.906700  0.890909  0.889446
# 4     noise  0.515909   0.266162  0.515909  0.351159
# 5      blur  0.937121   0.939813  0.937121  0.936939
#      L2-Norm
# 0   4.082597
# 1   5.224580
# 2   5.100508
# 3  10.068231
# 4   0.328173

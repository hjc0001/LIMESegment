# %%
import numpy as np
import matplotlib.pyplot as plt
import inspect
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd
import os

# %%
import importlib
import sys
sys.path.append('../')
from Utils.perturbationsnew import RBPIndividual, RBPIndividualNew1, RBPIndividualNew1fast, RBPIndividualNew2, zeroPerturb, noisePerturb, blurPerturb,multisamplebackgroundIdentification
from Utils.models import *
from Utils.data import perturb, generateSynthetic, generateSyntheticPerturbReal,ReadTS

print(sys.path)
# Out:
# ['/Users/gali/anaconda3/envs/LIMEtf/lib/python310.zip', '/Users/gali/anaconda3/envs/LIMEtf/lib/python3.10', '/Users/gali/anaconda3/envs/LIMEtf/lib/python3.10/lib-dynload', '', '/Users/gali/anaconda3/envs/LIMEtf/lib/python3.10/site-packages', '/Users/gali/anaconda3/envs/LIMEtf/lib/python3.10/site-packages/setuptools/_vendor', '../', '../']

# %% [markdown]
# ## Test important content removal (accuracy decrease)

# %% [markdown]
# ### Load synthetic dataset and train CNN model

# %%
x_train, y_train,x_test_original, y_test_original = ReadTS('FordB')
y_train = np.where(y_train == -1, 0, y_train)
y_test_original = np.where(y_test_original == -1, 0, y_test_original)
print(x_train.shape)
print(y_train)
# Out:
# (3636, 500, 1)
# [1. 0. 0. ... 1. 1. 1.]

# %%
from sklearn.preprocessing import StandardScaler
def normalize(TS):

    original_shape = TS.shape
    
    TS_2d = TS.reshape(original_shape[0] , original_shape[1])
    
    scaler = StandardScaler()
    
    TS_normalized = scaler.fit_transform(TS_2d)
    
    TS = TS_normalized.reshape(original_shape)
    
    return TS

x_train = normalize(x_train)
x_test_original = normalize(x_test_original)
#print(x_train[1])

# %%
model = make_CNN_model(x_train.shape[1:],num_classes = 2)
trained_model, history = train_CNN_model(model, x_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 2024-12-02 18:16:48.035264: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 91/91 [==============================] - 2s 20ms/step - loss: 0.4360 - sparse_categorical_accuracy: 0.8160 - val_loss: 1.0204 - val_sparse_categorical_accuracy: 0.4904
# Epoch 2/100
# 91/91 [==============================] - 2s 21ms/step - loss: 0.3467 - sparse_categorical_accuracy: 0.8587 - val_loss: 1.0432 - val_sparse_categorical_accuracy: 0.4904
# Epoch 3/100
# 91/91 [==============================] - 2s 22ms/step - loss: 0.3114 - sparse_categorical_accuracy: 0.8697 - val_loss: 1.0372 - val_sparse_categorical_accuracy: 0.4904
# Epoch 4/100
# 91/91 [==============================] - 2s 21ms/step - loss: 0.2991 - sparse_categorical_accuracy: 0.8728 - val_loss: 0.8119 - val_sparse_categorical_accuracy: 0.5385
# Epoch 5/100
# 91/91 [==============================] - 2s 21ms/step - loss: 0.2991 - sparse_categorical_accuracy: 0.8690 - val_loss: 0.5183 - val_sparse_categorical_accuracy: 0.7747
# Epoch 6/100
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2891 - sparse_categorical_accuracy: 0.8707 - val_loss: 0.4227 - val_sparse_categorical_accuracy: 0.7898
# Epoch 7/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2788 - sparse_categorical_accuracy: 0.8882 - val_loss: 0.4522 - val_sparse_categorical_accuracy: 0.7610
# Epoch 8/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2741 - sparse_categorical_accuracy: 0.8814 - val_loss: 0.4076 - val_sparse_categorical_accuracy: 0.8159
# Epoch 9/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2670 - sparse_categorical_accuracy: 0.8855 - val_loss: 0.4150 - val_sparse_categorical_accuracy: 0.7885
# Epoch 10/100
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2699 - sparse_categorical_accuracy: 0.8845 - val_loss: 0.5057 - val_sparse_categorical_accuracy: 0.7582
# Epoch 11/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2582 - sparse_categorical_accuracy: 0.8931 - val_loss: 0.4271 - val_sparse_categorical_accuracy: 0.7898
# Epoch 12/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2562 - sparse_categorical_accuracy: 0.8944 - val_loss: 0.5579 - val_sparse_categorical_accuracy: 0.7321
# Epoch 13/100
# 91/91 [==============================] - 2s 26ms/step - loss: 0.2601 - sparse_categorical_accuracy: 0.8913 - val_loss: 0.6503 - val_sparse_categorical_accuracy: 0.6676
# Epoch 14/100
# 91/91 [==============================] - 2s 27ms/step - loss: 0.2489 - sparse_categorical_accuracy: 0.8975 - val_loss: 0.5595 - val_sparse_categorical_accuracy: 0.7198
# Epoch 15/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2400 - sparse_categorical_accuracy: 0.8982 - val_loss: 1.1534 - val_sparse_categorical_accuracy: 0.5330
# Epoch 16/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2461 - sparse_categorical_accuracy: 0.9003 - val_loss: 0.3930 - val_sparse_categorical_accuracy: 0.8077
# Epoch 17/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2387 - sparse_categorical_accuracy: 0.9017 - val_loss: 0.4642 - val_sparse_categorical_accuracy: 0.7692
# Epoch 18/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2330 - sparse_categorical_accuracy: 0.9027 - val_loss: 0.3778 - val_sparse_categorical_accuracy: 0.8201
# Epoch 19/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2343 - sparse_categorical_accuracy: 0.9020 - val_loss: 0.4156 - val_sparse_categorical_accuracy: 0.7912
# Epoch 20/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2385 - sparse_categorical_accuracy: 0.8999 - val_loss: 0.9417 - val_sparse_categorical_accuracy: 0.5989
# Epoch 21/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2269 - sparse_categorical_accuracy: 0.9006 - val_loss: 0.3602 - val_sparse_categorical_accuracy: 0.8228
# Epoch 22/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2225 - sparse_categorical_accuracy: 0.9092 - val_loss: 0.5358 - val_sparse_categorical_accuracy: 0.7527
# Epoch 23/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2190 - sparse_categorical_accuracy: 0.9058 - val_loss: 0.3666 - val_sparse_categorical_accuracy: 0.8146
# Epoch 24/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2190 - sparse_categorical_accuracy: 0.9051 - val_loss: 0.7777 - val_sparse_categorical_accuracy: 0.6387
# Epoch 25/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2256 - sparse_categorical_accuracy: 0.9085 - val_loss: 0.5639 - val_sparse_categorical_accuracy: 0.7294
# Epoch 26/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2137 - sparse_categorical_accuracy: 0.9116 - val_loss: 0.3997 - val_sparse_categorical_accuracy: 0.8159
# Epoch 27/100
# 91/91 [==============================] - 2s 25ms/step - loss: 0.2187 - sparse_categorical_accuracy: 0.9089 - val_loss: 0.6414 - val_sparse_categorical_accuracy: 0.7582
# Epoch 28/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2032 - sparse_categorical_accuracy: 0.9130 - val_loss: 0.4308 - val_sparse_categorical_accuracy: 0.8008
# Epoch 29/100
# 91/91 [==============================] - 2s 25ms/step - loss: 0.2095 - sparse_categorical_accuracy: 0.9102 - val_loss: 0.7524 - val_sparse_categorical_accuracy: 0.7102
# Epoch 30/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2035 - sparse_categorical_accuracy: 0.9123 - val_loss: 0.3370 - val_sparse_categorical_accuracy: 0.8407
# Epoch 31/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2177 - sparse_categorical_accuracy: 0.9068 - val_loss: 0.3572 - val_sparse_categorical_accuracy: 0.8420
# Epoch 32/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2094 - sparse_categorical_accuracy: 0.9140 - val_loss: 0.7530 - val_sparse_categorical_accuracy: 0.7033
# Epoch 33/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1936 - sparse_categorical_accuracy: 0.9185 - val_loss: 0.5043 - val_sparse_categorical_accuracy: 0.7802
# Epoch 34/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2048 - sparse_categorical_accuracy: 0.9154 - val_loss: 0.3689 - val_sparse_categorical_accuracy: 0.8255
# Epoch 35/100
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2133 - sparse_categorical_accuracy: 0.9096 - val_loss: 0.5473 - val_sparse_categorical_accuracy: 0.7321
# Epoch 36/100
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2013 - sparse_categorical_accuracy: 0.9116 - val_loss: 0.3422 - val_sparse_categorical_accuracy: 0.8297
# Epoch 37/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2112 - sparse_categorical_accuracy: 0.9127 - val_loss: 0.4902 - val_sparse_categorical_accuracy: 0.7527
# Epoch 38/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2021 - sparse_categorical_accuracy: 0.9161 - val_loss: 0.3980 - val_sparse_categorical_accuracy: 0.8063
# Epoch 39/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2000 - sparse_categorical_accuracy: 0.9199 - val_loss: 0.4441 - val_sparse_categorical_accuracy: 0.8008
# Epoch 40/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1894 - sparse_categorical_accuracy: 0.9192 - val_loss: 0.3564 - val_sparse_categorical_accuracy: 0.8310
# Epoch 41/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1938 - sparse_categorical_accuracy: 0.9185 - val_loss: 0.3462 - val_sparse_categorical_accuracy: 0.8407
# Epoch 42/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1924 - sparse_categorical_accuracy: 0.9192 - val_loss: 0.3290 - val_sparse_categorical_accuracy: 0.8571
# Epoch 43/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1858 - sparse_categorical_accuracy: 0.9271 - val_loss: 0.5077 - val_sparse_categorical_accuracy: 0.7473
# Epoch 44/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1817 - sparse_categorical_accuracy: 0.9268 - val_loss: 1.0262 - val_sparse_categorical_accuracy: 0.5591
# Epoch 45/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1812 - sparse_categorical_accuracy: 0.9298 - val_loss: 0.7322 - val_sparse_categorical_accuracy: 0.6525
# Epoch 46/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1881 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.4500 - val_sparse_categorical_accuracy: 0.7953
# Epoch 47/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1766 - sparse_categorical_accuracy: 0.9298 - val_loss: 0.3417 - val_sparse_categorical_accuracy: 0.8503
# Epoch 48/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1781 - sparse_categorical_accuracy: 0.9268 - val_loss: 0.3193 - val_sparse_categorical_accuracy: 0.8819
# Epoch 49/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1712 - sparse_categorical_accuracy: 0.9274 - val_loss: 0.5568 - val_sparse_categorical_accuracy: 0.7431
# Epoch 50/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1721 - sparse_categorical_accuracy: 0.9292 - val_loss: 0.8586 - val_sparse_categorical_accuracy: 0.6250
# Epoch 51/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1694 - sparse_categorical_accuracy: 0.9312 - val_loss: 0.3110 - val_sparse_categorical_accuracy: 0.8819
# Epoch 52/100
# 91/91 [==============================] - 2s 25ms/step - loss: 0.1632 - sparse_categorical_accuracy: 0.9336 - val_loss: 2.1201 - val_sparse_categorical_accuracy: 0.6346
# Epoch 53/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1623 - sparse_categorical_accuracy: 0.9336 - val_loss: 0.3463 - val_sparse_categorical_accuracy: 0.8310
# Epoch 54/100
# 91/91 [==============================] - 2s 22ms/step - loss: 0.1579 - sparse_categorical_accuracy: 0.9340 - val_loss: 0.6285 - val_sparse_categorical_accuracy: 0.7170
# Epoch 55/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1730 - sparse_categorical_accuracy: 0.9292 - val_loss: 0.3439 - val_sparse_categorical_accuracy: 0.8558
# Epoch 56/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1683 - sparse_categorical_accuracy: 0.9309 - val_loss: 1.5102 - val_sparse_categorical_accuracy: 0.5536
# Epoch 57/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1611 - sparse_categorical_accuracy: 0.9388 - val_loss: 0.4245 - val_sparse_categorical_accuracy: 0.7953
# Epoch 58/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1589 - sparse_categorical_accuracy: 0.9378 - val_loss: 0.3139 - val_sparse_categorical_accuracy: 0.8819
# Epoch 59/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1676 - sparse_categorical_accuracy: 0.9360 - val_loss: 0.3715 - val_sparse_categorical_accuracy: 0.8352
# Epoch 60/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1583 - sparse_categorical_accuracy: 0.9367 - val_loss: 0.8034 - val_sparse_categorical_accuracy: 0.6566
# Epoch 61/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1564 - sparse_categorical_accuracy: 0.9412 - val_loss: 0.3553 - val_sparse_categorical_accuracy: 0.8544
# Epoch 62/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1551 - sparse_categorical_accuracy: 0.9374 - val_loss: 0.6933 - val_sparse_categorical_accuracy: 0.7459
# Epoch 63/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1554 - sparse_categorical_accuracy: 0.9391 - val_loss: 0.8172 - val_sparse_categorical_accuracy: 0.6909
# Epoch 64/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1563 - sparse_categorical_accuracy: 0.9354 - val_loss: 0.4456 - val_sparse_categorical_accuracy: 0.7967
# Epoch 65/100
# 91/91 [==============================] - 2s 22ms/step - loss: 0.1593 - sparse_categorical_accuracy: 0.9388 - val_loss: 0.3134 - val_sparse_categorical_accuracy: 0.8846
# Epoch 66/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1627 - sparse_categorical_accuracy: 0.9329 - val_loss: 0.7142 - val_sparse_categorical_accuracy: 0.7239
# Epoch 67/100
# 91/91 [==============================] - 2s 22ms/step - loss: 0.1598 - sparse_categorical_accuracy: 0.9347 - val_loss: 0.5939 - val_sparse_categorical_accuracy: 0.7761
# Epoch 68/100
# 91/91 [==============================] - 2s 25ms/step - loss: 0.1549 - sparse_categorical_accuracy: 0.9374 - val_loss: 0.6029 - val_sparse_categorical_accuracy: 0.7157
# Epoch 69/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1672 - sparse_categorical_accuracy: 0.9326 - val_loss: 0.3654 - val_sparse_categorical_accuracy: 0.8297
# Epoch 70/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1538 - sparse_categorical_accuracy: 0.9412 - val_loss: 0.7762 - val_sparse_categorical_accuracy: 0.7665
# Epoch 71/100
# 91/91 [==============================] - 2s 26ms/step - loss: 0.1477 - sparse_categorical_accuracy: 0.9405 - val_loss: 0.3414 - val_sparse_categorical_accuracy: 0.8585
# Epoch 72/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1559 - sparse_categorical_accuracy: 0.9371 - val_loss: 0.3301 - val_sparse_categorical_accuracy: 0.8571
# Epoch 73/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1499 - sparse_categorical_accuracy: 0.9384 - val_loss: 0.8346 - val_sparse_categorical_accuracy: 0.6511
# Epoch 74/100
# 91/91 [==============================] - 2s 22ms/step - loss: 0.1504 - sparse_categorical_accuracy: 0.9391 - val_loss: 0.5469 - val_sparse_categorical_accuracy: 0.7651
# Epoch 75/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1521 - sparse_categorical_accuracy: 0.9402 - val_loss: 0.4666 - val_sparse_categorical_accuracy: 0.7967
# Epoch 76/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1546 - sparse_categorical_accuracy: 0.9384 - val_loss: 0.7009 - val_sparse_categorical_accuracy: 0.6799
# Epoch 77/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1443 - sparse_categorical_accuracy: 0.9467 - val_loss: 0.5637 - val_sparse_categorical_accuracy: 0.7775
# Epoch 78/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1486 - sparse_categorical_accuracy: 0.9426 - val_loss: 0.4351 - val_sparse_categorical_accuracy: 0.8077
# Epoch 79/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1520 - sparse_categorical_accuracy: 0.9378 - val_loss: 0.3306 - val_sparse_categorical_accuracy: 0.8654
# Epoch 80/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1516 - sparse_categorical_accuracy: 0.9405 - val_loss: 0.4739 - val_sparse_categorical_accuracy: 0.7912
# Epoch 81/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1471 - sparse_categorical_accuracy: 0.9460 - val_loss: 0.6340 - val_sparse_categorical_accuracy: 0.7679
# Epoch 82/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1517 - sparse_categorical_accuracy: 0.9398 - val_loss: 0.4956 - val_sparse_categorical_accuracy: 0.8173
# Epoch 83/100
# 91/91 [==============================] - 2s 26ms/step - loss: 0.1584 - sparse_categorical_accuracy: 0.9357 - val_loss: 0.3212 - val_sparse_categorical_accuracy: 0.8887
# Epoch 84/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1552 - sparse_categorical_accuracy: 0.9429 - val_loss: 0.4249 - val_sparse_categorical_accuracy: 0.8255
# Epoch 85/100
# 91/91 [==============================] - 3s 30ms/step - loss: 0.1471 - sparse_categorical_accuracy: 0.9415 - val_loss: 0.3929 - val_sparse_categorical_accuracy: 0.8379
# Epoch 86/100
# 91/91 [==============================] - 3s 29ms/step - loss: 0.1499 - sparse_categorical_accuracy: 0.9402 - val_loss: 0.3735 - val_sparse_categorical_accuracy: 0.8626
# Epoch 87/100
# 91/91 [==============================] - 3s 31ms/step - loss: 0.1493 - sparse_categorical_accuracy: 0.9464 - val_loss: 0.7158 - val_sparse_categorical_accuracy: 0.7363
# Epoch 88/100
# 91/91 [==============================] - 3s 31ms/step - loss: 0.1488 - sparse_categorical_accuracy: 0.9443 - val_loss: 0.3566 - val_sparse_categorical_accuracy: 0.8379
# Epoch 89/100
# 91/91 [==============================] - 3s 29ms/step - loss: 0.1449 - sparse_categorical_accuracy: 0.9419 - val_loss: 0.3239 - val_sparse_categorical_accuracy: 0.8668
# Epoch 90/100
# 91/91 [==============================] - 3s 30ms/step - loss: 0.1411 - sparse_categorical_accuracy: 0.9464 - val_loss: 0.3268 - val_sparse_categorical_accuracy: 0.8846
# Epoch 91/100
# 91/91 [==============================] - 3s 30ms/step - loss: 0.1382 - sparse_categorical_accuracy: 0.9481 - val_loss: 0.5575 - val_sparse_categorical_accuracy: 0.7761
# Epoch 92/100
# 91/91 [==============================] - 3s 29ms/step - loss: 0.1452 - sparse_categorical_accuracy: 0.9433 - val_loss: 0.3602 - val_sparse_categorical_accuracy: 0.8544
# Epoch 93/100
# 91/91 [==============================] - 2s 27ms/step - loss: 0.1420 - sparse_categorical_accuracy: 0.9464 - val_loss: 0.3316 - val_sparse_categorical_accuracy: 0.8599
# Epoch 94/100
# 91/91 [==============================] - 3s 29ms/step - loss: 0.1412 - sparse_categorical_accuracy: 0.9433 - val_loss: 0.3304 - val_sparse_categorical_accuracy: 0.8709
# Epoch 95/100
# 91/91 [==============================] - 2s 27ms/step - loss: 0.1505 - sparse_categorical_accuracy: 0.9402 - val_loss: 0.4339 - val_sparse_categorical_accuracy: 0.8269
# Epoch 96/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1414 - sparse_categorical_accuracy: 0.9460 - val_loss: 0.3078 - val_sparse_categorical_accuracy: 0.8901
# Epoch 97/100
# 91/91 [==============================] - 2s 25ms/step - loss: 0.1483 - sparse_categorical_accuracy: 0.9429 - val_loss: 0.4092 - val_sparse_categorical_accuracy: 0.8214
# Epoch 98/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1452 - sparse_categorical_accuracy: 0.9436 - val_loss: 1.3178 - val_sparse_categorical_accuracy: 0.6854
# Epoch 99/100
# 91/91 [==============================] - 2s 25ms/step - loss: 0.1408 - sparse_categorical_accuracy: 0.9446 - val_loss: 0.3091 - val_sparse_categorical_accuracy: 0.8915
# Epoch 100/100
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1393 - sparse_categorical_accuracy: 0.9481 - val_loss: 0.3293 - val_sparse_categorical_accuracy: 0.8736

# %%
test_loss, test_acc = trained_model.evaluate(x_test_original, y_test_original)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5421 - sparse_categorical_accuracy: 0.7272
# Test accuracy 0.7271605134010315
# Test loss 0.5420840978622437

# %%
def l2norm(perturb):
    difference = perturb - x_test_original
    
    squared_difference = np.square(difference)
    
    sum_of_squares = np.sum(squared_difference, axis=1)
    
    l2_norms = np.sqrt(sum_of_squares)
    
    average_l2_norm = np.mean(l2_norms)
    
    print(average_l2_norm)

    return average_l2_norm


def perturb_predict(strategy,index_0,index_1):
    if strategy =='RBP1fast':
        bg = multisamplebackgroundIdentification(perturb_test_set)
        x_test_pert = np.asarray([perturb(strategy,x,index_0,index_1,bg = bg) for x in perturb_test_set])
        x_test_pert = np.expand_dims(x_test_pert, axis=-1)
        predictions_pert = model.predict(x_test_pert)
        predictions_pert = np.argmax(predictions_pert,axis=1)
    else:
        x_test_pert = np.asarray([perturb(strategy,x,index_0,index_1) for x in perturb_test_set])
        x_test_pert = np.expand_dims(x_test_pert, axis=-1)
        predictions_pert = model.predict(x_test_pert)
        predictions_pert = np.argmax(predictions_pert,axis=1)

    accuracy = accuracy_score(y_test_original, predictions_pert)
    precision = precision_score(y_test_original, predictions_pert, average='weighted')  
    recall = recall_score(y_test_original, predictions_pert, average='weighted')
    f1 = f1_score(y_test_original, predictions_pert, average='weighted')
    l2 = l2norm(x_test_pert)

    # print(strategy)
    # print(accuracy)
    # print(precision)
    # print(recall)
    # print(f1)

    return accuracy,precision,recall,f1,l2

# %%
perturb_test_set = x_test_original.copy()
perturb_test_set = perturb_test_set.reshape(x_test_original.shape[0:2])
index_0 = 30
index_1 = 60

strategies = ['RBP', 'RBP1fast', 'zero', 'noise', 'blur']

results = []
l2_results = []

for strategy in strategies:
    accuracy, precision, recall, f1, l2 = perturb_predict(strategy, index_0, index_1)
    results.append([strategy, accuracy, precision, recall, f1])
    l2_results.append(l2)

columns = ['Strategy', 'Accuracy', 'Precision', 'Recall', 'F1 Score']
df_results = pd.DataFrame(results, columns=columns)
l2_columns = ['L2-Norm']
l2_results = pd.DataFrame(l2_results, columns=l2_columns)

predictions_original = model.predict(x_test_original)
predictions_original = np.argmax(predictions_original,axis=1)
accuracy = accuracy_score(y_test_original, predictions_original)
precision = precision_score(y_test_original, predictions_original, average='weighted')  
recall = recall_score(y_test_original, predictions_original, average='weighted')
f1 = f1_score(y_test_original, predictions_original, average='weighted')
original_data = ['original', accuracy, precision, recall, f1]
df_results.loc[-1] = original_data  
df_results.index = df_results.index + 1  
df_results = df_results.sort_index()  

df_results.loc[2, 'Strategy'] = 'MRBP'

current_directory = os.getcwd()
result_folder = os.path.join(current_directory, 'result_data')

csv_path = os.path.join(result_folder, 'FordB.csv')
df_results.to_csv(csv_path, index=False)

csv_path = os.path.join(result_folder, 'FordBl2.csv')
l2_results.to_csv(csv_path, index=False)

print("done")
print(df_results)
print(l2_results)
# Out:
# 26/26 [==============================] - 0s 4ms/step
# 4.062573452895294
# 26/26 [==============================] - 0s 4ms/step
# 5.123610262748145
# 26/26 [==============================] - 0s 4ms/step
# 4.982823035558002
# 26/26 [==============================] - 0s 4ms/step
# 10.177306942080051
# 26/26 [==============================] - 0s 4ms/step
# 0.29620613062563506
#  1/26 [>.............................] - ETA: 0s
# /Users/gali/anaconda3/envs/LIMEtf/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 26/26 [==============================] - 0s 4ms/step
# done
#    Strategy  Accuracy  Precision    Recall  F1 Score
# 0  original  0.727160   0.733501  0.727160  0.724931
# 1       RBP  0.687654   0.741116  0.687654  0.670513
# 2      MRBP  0.571605   0.748207  0.571605  0.482382
# 3      zero  0.681481   0.753058  0.681481  0.658600
# 4     noise  0.495062   0.245086  0.495062  0.327861
# 5      blur  0.740741   0.746141  0.740741  0.739590
#      L2-Norm
# 0   4.062573
# 1   5.123610
# 2   4.982823
# 3  10.177307
# 4   0.296206

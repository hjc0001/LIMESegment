# %%
import numpy as np
import matplotlib.pyplot as plt
import inspect
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd
import os

# %%
import importlib
import sys
sys.path.append('../')
from Utils.perturbationsnew import RBPIndividual, RBPIndividualNew1, RBPIndividualNew1fast, RBPIndividualNew2, zeroPerturb, noisePerturb, blurPerturb,multisamplebackgroundIdentification
from Utils.models import *
from Utils.data import perturb, generateSynthetic, generateSyntheticPerturbReal,ReadTS

#print(sys.path)

# %% [markdown]
# ## Test important content removal (accuracy decrease)

# %% [markdown]
# ### Load synthetic dataset and train CNN model

# %%
x_train, y_train,x_test_original, y_test_original = ReadTS('Computers')
y_train = y_train - 1
y_test_original = y_test_original - 1
#print(x_train.shape)
#print(y_train)

# %%
from sklearn.preprocessing import StandardScaler
def normalize(TS):

    original_shape = TS.shape
    
    TS_2d = TS.reshape(original_shape[0] , original_shape[1])
    
    scaler = StandardScaler()
    
    TS_normalized = scaler.fit_transform(TS_2d)
    
    TS = TS_normalized.reshape(original_shape)
    
    return TS

x_train = normalize(x_train)
x_test_original = normalize(x_test_original)
#print(x_train[1])

# %%
model = make_CNN_model(x_train.shape[1:],num_classes = 2)
trained_model, history = train_CNN_model(model, x_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 2024-12-03 00:12:39.160017: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 7/7 [==============================] - 1s 44ms/step - loss: 0.6703 - sparse_categorical_accuracy: 0.5850 - val_loss: 0.7438 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 2/100
# 7/7 [==============================] - 0s 28ms/step - loss: 0.5601 - sparse_categorical_accuracy: 0.6550 - val_loss: 0.7600 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 3/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0.5338 - sparse_categorical_accuracy: 0.7400 - val_loss: 0.7638 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 4/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.5139 - sparse_categorical_accuracy: 0.7800 - val_loss: 0.7284 - val_sparse_categorical_accuracy: 0.1200
# Epoch 5/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.4982 - sparse_categorical_accuracy: 0.7800 - val_loss: 0.6988 - val_sparse_categorical_accuracy: 0.4600
# Epoch 6/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.4817 - sparse_categorical_accuracy: 0.7950 - val_loss: 0.6576 - val_sparse_categorical_accuracy: 0.7800
# Epoch 7/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.4666 - sparse_categorical_accuracy: 0.8200 - val_loss: 0.6324 - val_sparse_categorical_accuracy: 0.8800
# Epoch 8/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.4521 - sparse_categorical_accuracy: 0.8200 - val_loss: 0.5868 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.4729 - sparse_categorical_accuracy: 0.8000 - val_loss: 0.5569 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/100
# 7/7 [==============================] - 0s 26ms/step - loss: 0.4517 - sparse_categorical_accuracy: 0.8100 - val_loss: 0.5626 - val_sparse_categorical_accuracy: 0.9600
# Epoch 11/100
# 7/7 [==============================] - 0s 28ms/step - loss: 0.4304 - sparse_categorical_accuracy: 0.8250 - val_loss: 0.5460 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/100
# 7/7 [==============================] - 0s 28ms/step - loss: 0.4423 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.5116 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0.4625 - sparse_categorical_accuracy: 0.7450 - val_loss: 0.5352 - val_sparse_categorical_accuracy: 0.9000
# Epoch 14/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0.4052 - sparse_categorical_accuracy: 0.8500 - val_loss: 0.5520 - val_sparse_categorical_accuracy: 0.8200
# Epoch 15/100
# 7/7 [==============================] - 0s 25ms/step - loss: 0.4327 - sparse_categorical_accuracy: 0.8050 - val_loss: 0.5433 - val_sparse_categorical_accuracy: 0.9200
# Epoch 16/100
# 7/7 [==============================] - 0s 26ms/step - loss: 0.4121 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.5371 - val_sparse_categorical_accuracy: 0.8000
# Epoch 17/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.3948 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.4609 - val_sparse_categorical_accuracy: 0.9400
# Epoch 18/100
# 7/7 [==============================] - 0s 26ms/step - loss: 0.3749 - sparse_categorical_accuracy: 0.8450 - val_loss: 0.4830 - val_sparse_categorical_accuracy: 0.9200
# Epoch 19/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.3712 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.3562 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0.3413 - sparse_categorical_accuracy: 0.8600 - val_loss: 0.3845 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/100
# 7/7 [==============================] - 0s 26ms/step - loss: 0.3620 - sparse_categorical_accuracy: 0.8700 - val_loss: 0.3608 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.3376 - sparse_categorical_accuracy: 0.8500 - val_loss: 0.3412 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0.3276 - sparse_categorical_accuracy: 0.8600 - val_loss: 0.3467 - val_sparse_categorical_accuracy: 0.9800
# Epoch 24/100
# 7/7 [==============================] - 0s 28ms/step - loss: 0.3522 - sparse_categorical_accuracy: 0.8600 - val_loss: 0.3759 - val_sparse_categorical_accuracy: 0.8800
# Epoch 25/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.3146 - sparse_categorical_accuracy: 0.8750 - val_loss: 0.3695 - val_sparse_categorical_accuracy: 0.8800
# Epoch 26/100
# 7/7 [==============================] - 0s 28ms/step - loss: 0.3181 - sparse_categorical_accuracy: 0.8650 - val_loss: 0.4075 - val_sparse_categorical_accuracy: 0.8400
# Epoch 27/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.3274 - sparse_categorical_accuracy: 0.8700 - val_loss: 0.3143 - val_sparse_categorical_accuracy: 0.9800
# Epoch 28/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3079 - sparse_categorical_accuracy: 0.8950 - val_loss: 0.4903 - val_sparse_categorical_accuracy: 0.7400
# Epoch 29/100
# 7/7 [==============================] - 0s 28ms/step - loss: 0.3371 - sparse_categorical_accuracy: 0.8600 - val_loss: 0.4303 - val_sparse_categorical_accuracy: 0.8000
# Epoch 30/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.3243 - sparse_categorical_accuracy: 0.8900 - val_loss: 0.6076 - val_sparse_categorical_accuracy: 0.6400
# Epoch 31/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.3061 - sparse_categorical_accuracy: 0.8500 - val_loss: 0.4656 - val_sparse_categorical_accuracy: 0.7400
# Epoch 32/100
# 7/7 [==============================] - 0s 28ms/step - loss: 0.3272 - sparse_categorical_accuracy: 0.8750 - val_loss: 0.8300 - val_sparse_categorical_accuracy: 0.5200
# Epoch 33/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2962 - sparse_categorical_accuracy: 0.8900 - val_loss: 0.5166 - val_sparse_categorical_accuracy: 0.7000
# Epoch 34/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2887 - sparse_categorical_accuracy: 0.8750 - val_loss: 0.8003 - val_sparse_categorical_accuracy: 0.5400
# Epoch 35/100
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2770 - sparse_categorical_accuracy: 0.9000 - val_loss: 0.6586 - val_sparse_categorical_accuracy: 0.6600
# Epoch 36/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2776 - sparse_categorical_accuracy: 0.9050 - val_loss: 0.5868 - val_sparse_categorical_accuracy: 0.6600
# Epoch 37/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.2746 - sparse_categorical_accuracy: 0.8950 - val_loss: 1.1755 - val_sparse_categorical_accuracy: 0.4400
# Epoch 38/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.2852 - sparse_categorical_accuracy: 0.9000 - val_loss: 0.6705 - val_sparse_categorical_accuracy: 0.6200
# Epoch 39/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2784 - sparse_categorical_accuracy: 0.8800 - val_loss: 1.2367 - val_sparse_categorical_accuracy: 0.4200
# Epoch 40/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2828 - sparse_categorical_accuracy: 0.8850 - val_loss: 0.8402 - val_sparse_categorical_accuracy: 0.5400
# Epoch 41/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2744 - sparse_categorical_accuracy: 0.8750 - val_loss: 1.1348 - val_sparse_categorical_accuracy: 0.4600
# Epoch 42/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.3533 - sparse_categorical_accuracy: 0.8550 - val_loss: 0.9370 - val_sparse_categorical_accuracy: 0.5200
# Epoch 43/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2889 - sparse_categorical_accuracy: 0.9200 - val_loss: 1.3099 - val_sparse_categorical_accuracy: 0.4200
# Epoch 44/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3299 - sparse_categorical_accuracy: 0.8550 - val_loss: 2.4132 - val_sparse_categorical_accuracy: 0.1800
# Epoch 45/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.3091 - sparse_categorical_accuracy: 0.8800 - val_loss: 1.3758 - val_sparse_categorical_accuracy: 0.4400
# Epoch 46/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.3129 - sparse_categorical_accuracy: 0.8900 - val_loss: 0.7607 - val_sparse_categorical_accuracy: 0.6200
# Epoch 47/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2768 - sparse_categorical_accuracy: 0.9150 - val_loss: 1.2753 - val_sparse_categorical_accuracy: 0.4200
# Epoch 48/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2713 - sparse_categorical_accuracy: 0.9000 - val_loss: 1.1272 - val_sparse_categorical_accuracy: 0.5200
# Epoch 49/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2611 - sparse_categorical_accuracy: 0.8950 - val_loss: 1.1338 - val_sparse_categorical_accuracy: 0.5000
# Epoch 50/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3064 - sparse_categorical_accuracy: 0.8850 - val_loss: 1.2646 - val_sparse_categorical_accuracy: 0.4800
# Epoch 51/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2649 - sparse_categorical_accuracy: 0.9200 - val_loss: 1.4583 - val_sparse_categorical_accuracy: 0.4200
# Epoch 52/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2693 - sparse_categorical_accuracy: 0.9000 - val_loss: 1.8812 - val_sparse_categorical_accuracy: 0.3000
# Epoch 53/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2474 - sparse_categorical_accuracy: 0.9000 - val_loss: 1.4643 - val_sparse_categorical_accuracy: 0.4400
# Epoch 54/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2537 - sparse_categorical_accuracy: 0.8750 - val_loss: 2.0870 - val_sparse_categorical_accuracy: 0.2200
# Epoch 55/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2700 - sparse_categorical_accuracy: 0.9050 - val_loss: 1.6196 - val_sparse_categorical_accuracy: 0.3600
# Epoch 56/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2815 - sparse_categorical_accuracy: 0.8850 - val_loss: 1.9169 - val_sparse_categorical_accuracy: 0.2400
# Epoch 57/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2896 - sparse_categorical_accuracy: 0.8900 - val_loss: 1.8870 - val_sparse_categorical_accuracy: 0.2200
# Epoch 58/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2560 - sparse_categorical_accuracy: 0.8950 - val_loss: 1.3344 - val_sparse_categorical_accuracy: 0.4400
# Epoch 59/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2440 - sparse_categorical_accuracy: 0.9000 - val_loss: 2.0071 - val_sparse_categorical_accuracy: 0.1800
# Epoch 60/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.2906 - sparse_categorical_accuracy: 0.8800 - val_loss: 1.0757 - val_sparse_categorical_accuracy: 0.5800
# Epoch 61/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2612 - sparse_categorical_accuracy: 0.8950 - val_loss: 1.3178 - val_sparse_categorical_accuracy: 0.5200
# Epoch 62/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2669 - sparse_categorical_accuracy: 0.8950 - val_loss: 1.6581 - val_sparse_categorical_accuracy: 0.4600
# Epoch 63/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2505 - sparse_categorical_accuracy: 0.9050 - val_loss: 2.1839 - val_sparse_categorical_accuracy: 0.3400
# Epoch 64/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.2382 - sparse_categorical_accuracy: 0.9200 - val_loss: 2.4524 - val_sparse_categorical_accuracy: 0.1600
# Epoch 65/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2324 - sparse_categorical_accuracy: 0.9200 - val_loss: 1.9305 - val_sparse_categorical_accuracy: 0.4000
# Epoch 66/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2348 - sparse_categorical_accuracy: 0.9050 - val_loss: 2.3128 - val_sparse_categorical_accuracy: 0.4000
# Epoch 67/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2329 - sparse_categorical_accuracy: 0.9100 - val_loss: 1.1778 - val_sparse_categorical_accuracy: 0.5600
# Epoch 68/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2157 - sparse_categorical_accuracy: 0.9200 - val_loss: 2.4532 - val_sparse_categorical_accuracy: 0.2000
# Epoch 69/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2148 - sparse_categorical_accuracy: 0.9100 - val_loss: 2.0359 - val_sparse_categorical_accuracy: 0.3200
# Epoch 70/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2344 - sparse_categorical_accuracy: 0.9050 - val_loss: 1.9751 - val_sparse_categorical_accuracy: 0.3000
# Epoch 71/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2710 - sparse_categorical_accuracy: 0.8750 - val_loss: 2.2843 - val_sparse_categorical_accuracy: 0.2200
# Epoch 72/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2303 - sparse_categorical_accuracy: 0.9050 - val_loss: 2.0387 - val_sparse_categorical_accuracy: 0.3400
# Epoch 73/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.2243 - sparse_categorical_accuracy: 0.9050 - val_loss: 2.4330 - val_sparse_categorical_accuracy: 0.2000
# Epoch 74/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2805 - sparse_categorical_accuracy: 0.8900 - val_loss: 1.7022 - val_sparse_categorical_accuracy: 0.4800
# Epoch 75/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2448 - sparse_categorical_accuracy: 0.9050 - val_loss: 2.6100 - val_sparse_categorical_accuracy: 0.1800
# Epoch 76/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.2443 - sparse_categorical_accuracy: 0.9150 - val_loss: 2.4193 - val_sparse_categorical_accuracy: 0.2200
# Epoch 77/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2514 - sparse_categorical_accuracy: 0.9200 - val_loss: 3.1270 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 78/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2177 - sparse_categorical_accuracy: 0.9150 - val_loss: 2.6394 - val_sparse_categorical_accuracy: 0.1600
# Epoch 79/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2601 - sparse_categorical_accuracy: 0.9000 - val_loss: 3.3209 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 80/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2201 - sparse_categorical_accuracy: 0.9050 - val_loss: 3.3203 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 81/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2339 - sparse_categorical_accuracy: 0.8950 - val_loss: 5.1337 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 82/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2850 - sparse_categorical_accuracy: 0.9000 - val_loss: 5.7300 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 83/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2527 - sparse_categorical_accuracy: 0.9050 - val_loss: 2.2394 - val_sparse_categorical_accuracy: 0.2600
# Epoch 84/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2428 - sparse_categorical_accuracy: 0.9200 - val_loss: 1.1666 - val_sparse_categorical_accuracy: 0.6400
# Epoch 85/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2169 - sparse_categorical_accuracy: 0.9300 - val_loss: 2.8088 - val_sparse_categorical_accuracy: 0.0400
# Epoch 86/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2533 - sparse_categorical_accuracy: 0.9100 - val_loss: 1.2363 - val_sparse_categorical_accuracy: 0.5800
# Epoch 87/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2797 - sparse_categorical_accuracy: 0.8850 - val_loss: 0.5401 - val_sparse_categorical_accuracy: 0.7400
# Epoch 88/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2624 - sparse_categorical_accuracy: 0.9000 - val_loss: 1.3586 - val_sparse_categorical_accuracy: 0.5600
# Epoch 89/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2302 - sparse_categorical_accuracy: 0.9000 - val_loss: 1.1056 - val_sparse_categorical_accuracy: 0.6000
# Epoch 90/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2082 - sparse_categorical_accuracy: 0.9200 - val_loss: 2.7711 - val_sparse_categorical_accuracy: 0.2600
# Epoch 91/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2947 - sparse_categorical_accuracy: 0.8650 - val_loss: 1.8380 - val_sparse_categorical_accuracy: 0.5600
# Epoch 92/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2439 - sparse_categorical_accuracy: 0.8950 - val_loss: 1.4135 - val_sparse_categorical_accuracy: 0.6000
# Epoch 93/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2198 - sparse_categorical_accuracy: 0.9150 - val_loss: 0.7332 - val_sparse_categorical_accuracy: 0.7200
# Epoch 94/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2251 - sparse_categorical_accuracy: 0.9050 - val_loss: 2.2216 - val_sparse_categorical_accuracy: 0.5000
# Epoch 95/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2095 - sparse_categorical_accuracy: 0.9200 - val_loss: 3.3278 - val_sparse_categorical_accuracy: 0.3400
# Epoch 96/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2253 - sparse_categorical_accuracy: 0.9250 - val_loss: 2.0258 - val_sparse_categorical_accuracy: 0.5400
# Epoch 97/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1900 - sparse_categorical_accuracy: 0.9250 - val_loss: 2.6043 - val_sparse_categorical_accuracy: 0.4600
# Epoch 98/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2102 - sparse_categorical_accuracy: 0.9100 - val_loss: 2.1671 - val_sparse_categorical_accuracy: 0.5000
# Epoch 99/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.2062 - sparse_categorical_accuracy: 0.9300 - val_loss: 2.5034 - val_sparse_categorical_accuracy: 0.4400
# Epoch 100/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1996 - sparse_categorical_accuracy: 0.9050 - val_loss: 1.9811 - val_sparse_categorical_accuracy: 0.5000

# %%
test_loss, test_acc = trained_model.evaluate(x_test_original, y_test_original)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 8/8 [==============================] - 0s 8ms/step - loss: 0.9149 - sparse_categorical_accuracy: 0.7640
# Test accuracy 0.7639999985694885
# Test loss 0.9148957133293152

# %%
def l2norm(perturb):
    difference = perturb - x_test_original
    
    squared_difference = np.square(difference)
    
    sum_of_squares = np.sum(squared_difference, axis=1)
    
    l2_norms = np.sqrt(sum_of_squares)
    
    average_l2_norm = np.mean(l2_norms)
    
    #print(average_l2_norm)

    return average_l2_norm


def perturb_predict(strategy,index_0,index_1):
    if strategy =='RBP1fast':
        bg = multisamplebackgroundIdentification(perturb_test_set)
        x_test_pert = np.asarray([perturb(strategy,x,index_0,index_1,bg = bg) for x in perturb_test_set])
        x_test_pert = np.expand_dims(x_test_pert, axis=-1)
        predictions_pert = model.predict(x_test_pert)
        predictions_pert = np.argmax(predictions_pert,axis=1)
    else:
        x_test_pert = np.asarray([perturb(strategy,x,index_0,index_1) for x in perturb_test_set])
        x_test_pert = np.expand_dims(x_test_pert, axis=-1)
        predictions_pert = model.predict(x_test_pert)
        predictions_pert = np.argmax(predictions_pert,axis=1)

    accuracy = accuracy_score(y_test_original, predictions_pert)
    precision = precision_score(y_test_original, predictions_pert, average='weighted')  
    recall = recall_score(y_test_original, predictions_pert, average='weighted')
    f1 = f1_score(y_test_original, predictions_pert, average='weighted')
    l2 = l2norm(x_test_pert)

    # print(strategy)
    # print(accuracy)
    # print(precision)
    # print(recall)
    # print(f1)

    return accuracy,precision,recall,f1,l2

# %%
perturb_test_set = x_test_original.copy()
perturb_test_set = perturb_test_set.reshape(x_test_original.shape[0:2])
index_0 = 0
index_1 = 200

strategies = ['RBP', 'RBP1fast', 'zero', 'noise', 'blur']

results = []
l2_results = []

for strategy in strategies:
    accuracy, precision, recall, f1, l2 = perturb_predict(strategy, index_0, index_1)
    results.append([strategy, accuracy, precision, recall, f1])
    l2_results.append(l2)

columns = ['Strategy', 'Accuracy', 'Precision', 'Recall', 'F1 Score']
df_results = pd.DataFrame(results, columns=columns)
l2_columns = ['L2-Norm']
l2_results = pd.DataFrame(l2_results, columns=l2_columns)

predictions_original = model.predict(x_test_original)
predictions_original = np.argmax(predictions_original,axis=1)
accuracy = accuracy_score(y_test_original, predictions_original)
precision = precision_score(y_test_original, predictions_original, average='weighted')  
recall = recall_score(y_test_original, predictions_original, average='weighted')
f1 = f1_score(y_test_original, predictions_original, average='weighted')
original_data = ['original', accuracy, precision, recall, f1]
df_results.loc[-1] = original_data  
df_results.index = df_results.index + 1  
df_results = df_results.sort_index()  

df_results.loc[2, 'Strategy'] = 'MRBP'

current_directory = os.getcwd()
result_folder = os.path.join(current_directory, 'result_data')

csv_path = os.path.join(result_folder, 'Computers.csv')
df_results.to_csv(csv_path, index=False)

csv_path = os.path.join(result_folder, 'Computersl2.csv')
l2_results.to_csv(csv_path, index=False)

print("done")
print(df_results)
print(l2_results)
# Out:
# 8/8 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 6ms/step
# done
#    Strategy  Accuracy  Precision  Recall  F1 Score
# 0  original     0.764   0.776920   0.764  0.761215
# 1       RBP     0.740   0.742624   0.740  0.739295
# 2      MRBP     0.536   0.593423   0.536  0.451754
# 3      zero     0.724   0.724129   0.724  0.723960
# 4     noise     0.552   0.668954   0.552  0.458246
# 5      blur     0.740   0.745676   0.740  0.738490
#      L2-Norm
# 0   8.023789
# 1  10.853251
# 2  10.280979
# 3  36.742094
# 4   2.600488

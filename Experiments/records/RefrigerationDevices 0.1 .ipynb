# %%
import numpy as np
import matplotlib.pyplot as plt
import inspect

# %%
import importlib
import sys
sys.path.append('../')
from Utils.perturbationsnew import RBPIndividual, RBPIndividualNew1, RBPIndividualNew2, zeroPerturb, noisePerturb, blurPerturb
from Utils.models import *
from Utils.data import perturb, generateSynthetic, generateSyntheticPerturbReal,ReadTS

print(sys.path)
# Out:
# ['/Users/gali/anaconda3/envs/LIMEtf/lib/python310.zip', '/Users/gali/anaconda3/envs/LIMEtf/lib/python3.10', '/Users/gali/anaconda3/envs/LIMEtf/lib/python3.10/lib-dynload', '', '/Users/gali/anaconda3/envs/LIMEtf/lib/python3.10/site-packages', '/Users/gali/anaconda3/envs/LIMEtf/lib/python3.10/site-packages/setuptools/_vendor', '../', '../']

# %%
from IPython.display import display, HTML

display(HTML('''
<style>
.output {
    display: flex;
    flex-direction: column;
}
.output_scroll {
    max-height: 300px; 
    overflow-y: auto;
}
</style>
'''))
# Out:
# <style>
# .output {
#     display: flex;
#     flex-direction: column;
# }
# .output_scroll {
#     max-height: 300px;
#     overflow-y: auto;
# }
# </style>

# %% [markdown]
# ## Test important content removal (accuracy decrease)

# %% [markdown]
# ### Load synthetic dataset and train CNN model

# %%
x_train, y_train,x_test_original, y_test_original = ReadTS('RefrigerationDevices')
y_train = y_train - 1
y_test_original = y_test_original - 1
#print(x_train.shape)
#print(y_train)

# %%
from sklearn.preprocessing import StandardScaler
def normalize(TS):

    original_shape = TS.shape
    

    TS_2d = TS.reshape(original_shape[0] , original_shape[1])
    

    scaler = StandardScaler()
    

    TS_normalized = scaler.fit_transform(TS_2d)

    
    TS = TS_normalized.reshape(original_shape)
    
    return TS

x_train = normalize(x_train)
x_test_original = normalize(x_test_original)

# %%
model = make_CNN_model(x_train.shape[1:],num_classes = 3)
trained_model, history = train_CNN_model(model, x_train, y_train, epochs=150, batch_size=32)
# Out:
# Epoch 1/150
# 10/10 [==============================] - 1s 43ms/step - loss: 0.9386 - sparse_categorical_accuracy: 0.5200 - val_loss: 1.1349 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 2/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.7957 - sparse_categorical_accuracy: 0.6633 - val_loss: 1.1530 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 3/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.7744 - sparse_categorical_accuracy: 0.6533 - val_loss: 1.1595 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 4/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.7318 - sparse_categorical_accuracy: 0.6700 - val_loss: 1.2223 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 5/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.7252 - sparse_categorical_accuracy: 0.6867 - val_loss: 1.2410 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 6/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.7178 - sparse_categorical_accuracy: 0.6900 - val_loss: 1.2615 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 7/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.7031 - sparse_categorical_accuracy: 0.6800 - val_loss: 1.2858 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 8/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.6733 - sparse_categorical_accuracy: 0.6867 - val_loss: 1.2765 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 9/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.6640 - sparse_categorical_accuracy: 0.6933 - val_loss: 1.2635 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 10/150
# 10/10 [==============================] - 0s 30ms/step - loss: 0.6573 - sparse_categorical_accuracy: 0.6967 - val_loss: 1.3503 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 11/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.6553 - sparse_categorical_accuracy: 0.7200 - val_loss: 1.4183 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 12/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.6477 - sparse_categorical_accuracy: 0.7100 - val_loss: 1.3792 - val_sparse_categorical_accuracy: 0.0133
# Epoch 13/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.6572 - sparse_categorical_accuracy: 0.7000 - val_loss: 1.4694 - val_sparse_categorical_accuracy: 0.0267
# Epoch 14/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.6348 - sparse_categorical_accuracy: 0.7200 - val_loss: 1.4880 - val_sparse_categorical_accuracy: 0.0933
# Epoch 15/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.6150 - sparse_categorical_accuracy: 0.7200 - val_loss: 1.6380 - val_sparse_categorical_accuracy: 0.0267
# Epoch 16/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.6238 - sparse_categorical_accuracy: 0.7200 - val_loss: 1.6727 - val_sparse_categorical_accuracy: 0.0800
# Epoch 17/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.6063 - sparse_categorical_accuracy: 0.7267 - val_loss: 1.7074 - val_sparse_categorical_accuracy: 0.0800
# Epoch 18/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.6061 - sparse_categorical_accuracy: 0.7267 - val_loss: 1.7116 - val_sparse_categorical_accuracy: 0.0800
# Epoch 19/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.6250 - sparse_categorical_accuracy: 0.7167 - val_loss: 1.8058 - val_sparse_categorical_accuracy: 0.0667
# Epoch 20/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.6218 - sparse_categorical_accuracy: 0.7033 - val_loss: 1.7535 - val_sparse_categorical_accuracy: 0.1067
# Epoch 21/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.5984 - sparse_categorical_accuracy: 0.7300 - val_loss: 1.7549 - val_sparse_categorical_accuracy: 0.1067
# Epoch 22/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.6025 - sparse_categorical_accuracy: 0.7300 - val_loss: 1.8210 - val_sparse_categorical_accuracy: 0.1067
# Epoch 23/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.5964 - sparse_categorical_accuracy: 0.7567 - val_loss: 1.7047 - val_sparse_categorical_accuracy: 0.0800
# Epoch 24/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.6186 - sparse_categorical_accuracy: 0.7067 - val_loss: 2.0110 - val_sparse_categorical_accuracy: 0.0800
# Epoch 25/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.5956 - sparse_categorical_accuracy: 0.7233 - val_loss: 2.0019 - val_sparse_categorical_accuracy: 0.0667
# Epoch 26/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.6320 - sparse_categorical_accuracy: 0.7267 - val_loss: 1.8766 - val_sparse_categorical_accuracy: 0.0800
# Epoch 27/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.6165 - sparse_categorical_accuracy: 0.7233 - val_loss: 1.6524 - val_sparse_categorical_accuracy: 0.0800
# Epoch 28/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.6157 - sparse_categorical_accuracy: 0.7367 - val_loss: 1.8153 - val_sparse_categorical_accuracy: 0.0667
# Epoch 29/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.6069 - sparse_categorical_accuracy: 0.7267 - val_loss: 1.9804 - val_sparse_categorical_accuracy: 0.0800
# Epoch 30/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.5915 - sparse_categorical_accuracy: 0.7400 - val_loss: 1.8565 - val_sparse_categorical_accuracy: 0.0800
# Epoch 31/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.5682 - sparse_categorical_accuracy: 0.7433 - val_loss: 1.8707 - val_sparse_categorical_accuracy: 0.0800
# Epoch 32/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.5755 - sparse_categorical_accuracy: 0.7367 - val_loss: 1.9942 - val_sparse_categorical_accuracy: 0.0667
# Epoch 33/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.5671 - sparse_categorical_accuracy: 0.7467 - val_loss: 2.0658 - val_sparse_categorical_accuracy: 0.0800
# Epoch 34/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.5777 - sparse_categorical_accuracy: 0.7333 - val_loss: 2.3135 - val_sparse_categorical_accuracy: 0.0533
# Epoch 35/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.5975 - sparse_categorical_accuracy: 0.7367 - val_loss: 2.0629 - val_sparse_categorical_accuracy: 0.1600
# Epoch 36/150
# 10/10 [==============================] - 0s 30ms/step - loss: 0.5612 - sparse_categorical_accuracy: 0.7667 - val_loss: 2.1199 - val_sparse_categorical_accuracy: 0.0933
# Epoch 37/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.5923 - sparse_categorical_accuracy: 0.7500 - val_loss: 2.0801 - val_sparse_categorical_accuracy: 0.1333
# Epoch 38/150
# 10/10 [==============================] - 0s 30ms/step - loss: 0.5730 - sparse_categorical_accuracy: 0.7300 - val_loss: 2.0726 - val_sparse_categorical_accuracy: 0.1867
# Epoch 39/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.5480 - sparse_categorical_accuracy: 0.7733 - val_loss: 2.1676 - val_sparse_categorical_accuracy: 0.1067
# Epoch 40/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.5565 - sparse_categorical_accuracy: 0.7567 - val_loss: 2.3123 - val_sparse_categorical_accuracy: 0.1200
# Epoch 41/150
# 10/10 [==============================] - 0s 30ms/step - loss: 0.5861 - sparse_categorical_accuracy: 0.7300 - val_loss: 2.4936 - val_sparse_categorical_accuracy: 0.1333
# Epoch 42/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.5713 - sparse_categorical_accuracy: 0.7667 - val_loss: 2.4522 - val_sparse_categorical_accuracy: 0.1733
# Epoch 43/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.6017 - sparse_categorical_accuracy: 0.7333 - val_loss: 2.1486 - val_sparse_categorical_accuracy: 0.1200
# Epoch 44/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.5723 - sparse_categorical_accuracy: 0.7800 - val_loss: 2.5332 - val_sparse_categorical_accuracy: 0.1067
# Epoch 45/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.5848 - sparse_categorical_accuracy: 0.7333 - val_loss: 2.9730 - val_sparse_categorical_accuracy: 0.1067
# Epoch 46/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.5455 - sparse_categorical_accuracy: 0.7800 - val_loss: 2.3725 - val_sparse_categorical_accuracy: 0.1733
# Epoch 47/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.5649 - sparse_categorical_accuracy: 0.7700 - val_loss: 2.4337 - val_sparse_categorical_accuracy: 0.1067
# Epoch 48/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.5523 - sparse_categorical_accuracy: 0.7767 - val_loss: 2.2912 - val_sparse_categorical_accuracy: 0.1867
# Epoch 49/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.5528 - sparse_categorical_accuracy: 0.7500 - val_loss: 2.8054 - val_sparse_categorical_accuracy: 0.0667
# Epoch 50/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.5860 - sparse_categorical_accuracy: 0.7367 - val_loss: 2.7780 - val_sparse_categorical_accuracy: 0.1333
# Epoch 51/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.5470 - sparse_categorical_accuracy: 0.7700 - val_loss: 2.8316 - val_sparse_categorical_accuracy: 0.0400
# Epoch 52/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.5380 - sparse_categorical_accuracy: 0.7733 - val_loss: 2.6950 - val_sparse_categorical_accuracy: 0.1600
# Epoch 53/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.5354 - sparse_categorical_accuracy: 0.7700 - val_loss: 2.7452 - val_sparse_categorical_accuracy: 0.0933
# Epoch 54/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.5271 - sparse_categorical_accuracy: 0.7833 - val_loss: 2.4976 - val_sparse_categorical_accuracy: 0.1733
# Epoch 55/150
# 10/10 [==============================] - 0s 30ms/step - loss: 0.5292 - sparse_categorical_accuracy: 0.7667 - val_loss: 2.3379 - val_sparse_categorical_accuracy: 0.2133
# Epoch 56/150
# 10/10 [==============================] - 0s 30ms/step - loss: 0.5127 - sparse_categorical_accuracy: 0.7933 - val_loss: 2.4602 - val_sparse_categorical_accuracy: 0.1467
# Epoch 57/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.5057 - sparse_categorical_accuracy: 0.8033 - val_loss: 2.4643 - val_sparse_categorical_accuracy: 0.2000
# Epoch 58/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.4993 - sparse_categorical_accuracy: 0.7900 - val_loss: 2.9659 - val_sparse_categorical_accuracy: 0.0267
# Epoch 59/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.5301 - sparse_categorical_accuracy: 0.7800 - val_loss: 3.1186 - val_sparse_categorical_accuracy: 0.0400
# Epoch 60/150
# 10/10 [==============================] - 0s 30ms/step - loss: 0.4886 - sparse_categorical_accuracy: 0.8067 - val_loss: 3.1326 - val_sparse_categorical_accuracy: 0.1200
# Epoch 61/150
# 10/10 [==============================] - 0s 36ms/step - loss: 0.5002 - sparse_categorical_accuracy: 0.7900 - val_loss: 3.2341 - val_sparse_categorical_accuracy: 0.1067
# Epoch 62/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.5051 - sparse_categorical_accuracy: 0.7900 - val_loss: 3.6856 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 63/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.5249 - sparse_categorical_accuracy: 0.7733 - val_loss: 3.0828 - val_sparse_categorical_accuracy: 0.0133
# Epoch 64/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.5279 - sparse_categorical_accuracy: 0.7833 - val_loss: 2.8189 - val_sparse_categorical_accuracy: 0.2000
# Epoch 65/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.5607 - sparse_categorical_accuracy: 0.7567 - val_loss: 3.2154 - val_sparse_categorical_accuracy: 0.0533
# Epoch 66/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.5062 - sparse_categorical_accuracy: 0.8067 - val_loss: 2.5905 - val_sparse_categorical_accuracy: 0.1867
# Epoch 67/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4906 - sparse_categorical_accuracy: 0.8100 - val_loss: 2.5702 - val_sparse_categorical_accuracy: 0.1867
# Epoch 68/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.4940 - sparse_categorical_accuracy: 0.7900 - val_loss: 2.9395 - val_sparse_categorical_accuracy: 0.0267
# Epoch 69/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4912 - sparse_categorical_accuracy: 0.8033 - val_loss: 3.4218 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 70/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.5055 - sparse_categorical_accuracy: 0.7700 - val_loss: 2.8511 - val_sparse_categorical_accuracy: 0.1333
# Epoch 71/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.5266 - sparse_categorical_accuracy: 0.7700 - val_loss: 3.0167 - val_sparse_categorical_accuracy: 0.0400
# Epoch 72/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.5118 - sparse_categorical_accuracy: 0.8000 - val_loss: 3.3916 - val_sparse_categorical_accuracy: 0.0267
# Epoch 73/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4891 - sparse_categorical_accuracy: 0.7900 - val_loss: 2.9109 - val_sparse_categorical_accuracy: 0.1867
# Epoch 74/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.4761 - sparse_categorical_accuracy: 0.8000 - val_loss: 3.7006 - val_sparse_categorical_accuracy: 0.0267
# Epoch 75/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.5027 - sparse_categorical_accuracy: 0.7800 - val_loss: 3.8256 - val_sparse_categorical_accuracy: 0.0133
# Epoch 76/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.5068 - sparse_categorical_accuracy: 0.7833 - val_loss: 4.0600 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 77/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4941 - sparse_categorical_accuracy: 0.8000 - val_loss: 5.4597 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 78/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.5602 - sparse_categorical_accuracy: 0.7700 - val_loss: 3.1269 - val_sparse_categorical_accuracy: 0.0267
# Epoch 79/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4910 - sparse_categorical_accuracy: 0.7967 - val_loss: 4.8209 - val_sparse_categorical_accuracy: 0.0400
# Epoch 80/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4930 - sparse_categorical_accuracy: 0.8200 - val_loss: 3.5474 - val_sparse_categorical_accuracy: 0.0400
# Epoch 81/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.5127 - sparse_categorical_accuracy: 0.7933 - val_loss: 5.6414 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 82/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4779 - sparse_categorical_accuracy: 0.7933 - val_loss: 4.7426 - val_sparse_categorical_accuracy: 0.0400
# Epoch 83/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.4987 - sparse_categorical_accuracy: 0.7900 - val_loss: 3.3456 - val_sparse_categorical_accuracy: 0.0400
# Epoch 84/150
# 10/10 [==============================] - 0s 35ms/step - loss: 0.4615 - sparse_categorical_accuracy: 0.8167 - val_loss: 5.3814 - val_sparse_categorical_accuracy: 0.0400
# Epoch 85/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4760 - sparse_categorical_accuracy: 0.8300 - val_loss: 3.2254 - val_sparse_categorical_accuracy: 0.0667
# Epoch 86/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.4692 - sparse_categorical_accuracy: 0.8133 - val_loss: 7.1172 - val_sparse_categorical_accuracy: 0.0400
# Epoch 87/150
# 10/10 [==============================] - 0s 35ms/step - loss: 0.4842 - sparse_categorical_accuracy: 0.7967 - val_loss: 2.8950 - val_sparse_categorical_accuracy: 0.0800
# Epoch 88/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4877 - sparse_categorical_accuracy: 0.7833 - val_loss: 6.9442 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 89/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.4971 - sparse_categorical_accuracy: 0.8033 - val_loss: 8.6164 - val_sparse_categorical_accuracy: 0.0267
# Epoch 90/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4996 - sparse_categorical_accuracy: 0.7667 - val_loss: 3.4227 - val_sparse_categorical_accuracy: 0.0533
# Epoch 91/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.4972 - sparse_categorical_accuracy: 0.7900 - val_loss: 5.8313 - val_sparse_categorical_accuracy: 0.0400
# Epoch 92/150
# 10/10 [==============================] - 0s 36ms/step - loss: 0.4859 - sparse_categorical_accuracy: 0.7667 - val_loss: 3.4097 - val_sparse_categorical_accuracy: 0.0400
# Epoch 93/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4589 - sparse_categorical_accuracy: 0.8133 - val_loss: 4.1190 - val_sparse_categorical_accuracy: 0.0400
# Epoch 94/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.4698 - sparse_categorical_accuracy: 0.8367 - val_loss: 3.1644 - val_sparse_categorical_accuracy: 0.1867
# Epoch 95/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4628 - sparse_categorical_accuracy: 0.8300 - val_loss: 4.0456 - val_sparse_categorical_accuracy: 0.0267
# Epoch 96/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4680 - sparse_categorical_accuracy: 0.8100 - val_loss: 4.4927 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 97/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.4806 - sparse_categorical_accuracy: 0.8067 - val_loss: 5.9906 - val_sparse_categorical_accuracy: 0.0400
# Epoch 98/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4538 - sparse_categorical_accuracy: 0.7967 - val_loss: 3.2487 - val_sparse_categorical_accuracy: 0.0933
# Epoch 99/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4416 - sparse_categorical_accuracy: 0.8233 - val_loss: 3.6680 - val_sparse_categorical_accuracy: 0.0400
# Epoch 100/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4609 - sparse_categorical_accuracy: 0.8400 - val_loss: 3.5597 - val_sparse_categorical_accuracy: 0.0533
# Epoch 101/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4499 - sparse_categorical_accuracy: 0.8067 - val_loss: 3.3204 - val_sparse_categorical_accuracy: 0.0800
# Epoch 102/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4475 - sparse_categorical_accuracy: 0.8233 - val_loss: 4.3406 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 103/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4463 - sparse_categorical_accuracy: 0.8367 - val_loss: 3.3587 - val_sparse_categorical_accuracy: 0.0800
# Epoch 104/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4268 - sparse_categorical_accuracy: 0.8533 - val_loss: 2.7742 - val_sparse_categorical_accuracy: 0.1333
# Epoch 105/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.4533 - sparse_categorical_accuracy: 0.8333 - val_loss: 3.9782 - val_sparse_categorical_accuracy: 0.0400
# Epoch 106/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4720 - sparse_categorical_accuracy: 0.8200 - val_loss: 3.4317 - val_sparse_categorical_accuracy: 0.1333
# Epoch 107/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4277 - sparse_categorical_accuracy: 0.8467 - val_loss: 2.4654 - val_sparse_categorical_accuracy: 0.3067
# Epoch 108/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4515 - sparse_categorical_accuracy: 0.8167 - val_loss: 4.3428 - val_sparse_categorical_accuracy: 0.0267
# Epoch 109/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4360 - sparse_categorical_accuracy: 0.8433 - val_loss: 3.3615 - val_sparse_categorical_accuracy: 0.2133
# Epoch 110/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4653 - sparse_categorical_accuracy: 0.7833 - val_loss: 3.6203 - val_sparse_categorical_accuracy: 0.0400
# Epoch 111/150
# 10/10 [==============================] - 0s 35ms/step - loss: 0.4546 - sparse_categorical_accuracy: 0.8133 - val_loss: 2.9840 - val_sparse_categorical_accuracy: 0.2000
# Epoch 112/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4438 - sparse_categorical_accuracy: 0.8133 - val_loss: 3.3814 - val_sparse_categorical_accuracy: 0.0400
# Epoch 113/150
# 10/10 [==============================] - 0s 35ms/step - loss: 0.4411 - sparse_categorical_accuracy: 0.8400 - val_loss: 3.1849 - val_sparse_categorical_accuracy: 0.0400
# Epoch 114/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.4467 - sparse_categorical_accuracy: 0.8167 - val_loss: 3.3065 - val_sparse_categorical_accuracy: 0.1067
# Epoch 115/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4267 - sparse_categorical_accuracy: 0.8300 - val_loss: 3.5002 - val_sparse_categorical_accuracy: 0.0400
# Epoch 116/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4326 - sparse_categorical_accuracy: 0.8400 - val_loss: 3.1722 - val_sparse_categorical_accuracy: 0.0933
# Epoch 117/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4379 - sparse_categorical_accuracy: 0.8467 - val_loss: 2.8282 - val_sparse_categorical_accuracy: 0.1467
# Epoch 118/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.4763 - sparse_categorical_accuracy: 0.8200 - val_loss: 3.7250 - val_sparse_categorical_accuracy: 0.0533
# Epoch 119/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4544 - sparse_categorical_accuracy: 0.8167 - val_loss: 3.1379 - val_sparse_categorical_accuracy: 0.1067
# Epoch 120/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4780 - sparse_categorical_accuracy: 0.7967 - val_loss: 2.3943 - val_sparse_categorical_accuracy: 0.2400
# Epoch 121/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4589 - sparse_categorical_accuracy: 0.8200 - val_loss: 3.9796 - val_sparse_categorical_accuracy: 0.0400
# Epoch 122/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4373 - sparse_categorical_accuracy: 0.8067 - val_loss: 3.2963 - val_sparse_categorical_accuracy: 0.1333
# Epoch 123/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4141 - sparse_categorical_accuracy: 0.8267 - val_loss: 3.5601 - val_sparse_categorical_accuracy: 0.0533
# Epoch 124/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.4131 - sparse_categorical_accuracy: 0.8400 - val_loss: 3.7514 - val_sparse_categorical_accuracy: 0.0400
# Epoch 125/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4142 - sparse_categorical_accuracy: 0.8433 - val_loss: 3.9087 - val_sparse_categorical_accuracy: 0.0400
# Epoch 126/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4279 - sparse_categorical_accuracy: 0.8333 - val_loss: 3.3225 - val_sparse_categorical_accuracy: 0.0533
# Epoch 127/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.4024 - sparse_categorical_accuracy: 0.8467 - val_loss: 3.4441 - val_sparse_categorical_accuracy: 0.0667
# Epoch 128/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.3961 - sparse_categorical_accuracy: 0.8500 - val_loss: 3.6147 - val_sparse_categorical_accuracy: 0.0400
# Epoch 129/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4108 - sparse_categorical_accuracy: 0.8300 - val_loss: 3.2505 - val_sparse_categorical_accuracy: 0.0400
# Epoch 130/150
# 10/10 [==============================] - 0s 34ms/step - loss: 0.4056 - sparse_categorical_accuracy: 0.8367 - val_loss: 3.4655 - val_sparse_categorical_accuracy: 0.0400
# Epoch 131/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.3855 - sparse_categorical_accuracy: 0.8533 - val_loss: 3.8467 - val_sparse_categorical_accuracy: 0.0400
# Epoch 132/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.3989 - sparse_categorical_accuracy: 0.8367 - val_loss: 3.2364 - val_sparse_categorical_accuracy: 0.1467
# Epoch 133/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.3955 - sparse_categorical_accuracy: 0.8533 - val_loss: 3.5008 - val_sparse_categorical_accuracy: 0.0400
# Epoch 134/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4023 - sparse_categorical_accuracy: 0.8433 - val_loss: 4.3750 - val_sparse_categorical_accuracy: 0.0400
# Epoch 135/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4290 - sparse_categorical_accuracy: 0.8267 - val_loss: 4.0774 - val_sparse_categorical_accuracy: 0.0400
# Epoch 136/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4152 - sparse_categorical_accuracy: 0.8533 - val_loss: 3.9050 - val_sparse_categorical_accuracy: 0.0400
# Epoch 137/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.3935 - sparse_categorical_accuracy: 0.8633 - val_loss: 5.1035 - val_sparse_categorical_accuracy: 0.0400
# Epoch 138/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4154 - sparse_categorical_accuracy: 0.8200 - val_loss: 6.1477 - val_sparse_categorical_accuracy: 0.0267
# Epoch 139/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4415 - sparse_categorical_accuracy: 0.8000 - val_loss: 4.7810 - val_sparse_categorical_accuracy: 0.0400
# Epoch 140/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4193 - sparse_categorical_accuracy: 0.8667 - val_loss: 5.1824 - val_sparse_categorical_accuracy: 0.0400
# Epoch 141/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.3981 - sparse_categorical_accuracy: 0.8367 - val_loss: 4.8832 - val_sparse_categorical_accuracy: 0.0400
# Epoch 142/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.4132 - sparse_categorical_accuracy: 0.8333 - val_loss: 4.7822 - val_sparse_categorical_accuracy: 0.0400
# Epoch 143/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.3971 - sparse_categorical_accuracy: 0.8267 - val_loss: 4.1463 - val_sparse_categorical_accuracy: 0.0267
# Epoch 144/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.3768 - sparse_categorical_accuracy: 0.8633 - val_loss: 4.1506 - val_sparse_categorical_accuracy: 0.0267
# Epoch 145/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.3737 - sparse_categorical_accuracy: 0.8433 - val_loss: 3.5975 - val_sparse_categorical_accuracy: 0.0933
# Epoch 146/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.4286 - sparse_categorical_accuracy: 0.8233 - val_loss: 3.5297 - val_sparse_categorical_accuracy: 0.0533
# Epoch 147/150
# 10/10 [==============================] - 0s 31ms/step - loss: 0.3740 - sparse_categorical_accuracy: 0.8633 - val_loss: 3.2516 - val_sparse_categorical_accuracy: 0.1600
# Epoch 148/150
# 10/10 [==============================] - 0s 33ms/step - loss: 0.3630 - sparse_categorical_accuracy: 0.8633 - val_loss: 4.0514 - val_sparse_categorical_accuracy: 0.0400
# Epoch 149/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.3739 - sparse_categorical_accuracy: 0.8567 - val_loss: 3.0558 - val_sparse_categorical_accuracy: 0.1333
# Epoch 150/150
# 10/10 [==============================] - 0s 32ms/step - loss: 0.3812 - sparse_categorical_accuracy: 0.8433 - val_loss: 3.7886 - val_sparse_categorical_accuracy: 0.0400

# %%
test_loss, test_acc = trained_model.evaluate(x_test_original, y_test_original)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 12/12 [==============================] - 0s 7ms/step - loss: 2.5424 - sparse_categorical_accuracy: 0.4827
# Test accuracy 0.48266667127609253
# Test loss 2.5424389839172363

# %% [markdown]
# ### Create perturbed test sets and calculate decrease in accuracy

# %%
print(y_test_original.shape)
# Out:
# (375,)

# %%
print(inspect.getsource(perturb))
print(inspect.signature(perturb))
# Out:
# def perturb(perturbation_strategy, ts, index0, index1, global_ts = [],bg = []):
#     if perturbation_strategy == 'RBP':
#         return RBPIndividual(ts, index0, index1)
#     if perturbation_strategy == 'zero':
#         return zeroPerturb(ts, index0, index1)
#     if perturbation_strategy == 'noise':
#         return noisePerturb(ts, index0, index1)
#     if perturbation_strategy == 'blur':
#         return blurPerturb(ts, index0, index1)
#     if perturbation_strategy == 'RBP1':
#         return RBPIndividualNew1(global_ts, ts, index0, index1)
#     if perturbation_strategy == 'RBP1fast':
#         return RBPIndividualNew1fast(bg, ts, index0, index1)
#     if perturbation_strategy == 'RBP2':
#         return RBPIndividualNew2(global_ts, ts, index0, index1)
#
# (perturbation_strategy, ts, index0, index1, global_ts=[], bg=[])

# %%
predictions_original = model.predict(x_test_original)
perturb_test_set = x_test_original.copy()
perturb_test_set = perturb_test_set.reshape(x_test_original.shape[0:2])
index_0 = 200
index_1 = 400

x_test_rbp = np.asarray([perturb('RBP',x,index_0,index_1) for x in perturb_test_set])
x_test_rbp = np.expand_dims(x_test_rbp, axis=-1)
predictions_rbp = model.predict(x_test_rbp)

pert1 = perturb('RBP1',perturb_test_set[0],index_0,index_1, global_ts = perturb_test_set)
x_test_new1 = np.asarray([perturb('RBP1',x,index_0,index_1, global_ts = perturb_test_set) for x in perturb_test_set])
x_test_new1 = np.expand_dims(x_test_new1, axis=-1)
predictions_new1 = model.predict(x_test_new1)

#x_test_new2 = np.asarray([perturb('RBP2',x,400,500, global_ts = perturb_test_set) for x in perturb_test_set])
#x_test_new2 = np.expand_dims(x_test_new2, axis=-1)
#predictions_new2 = model.predict(x_test_new2)

x_test_zero = np.asarray([perturb('zero',x,index_0,index_1) for x in perturb_test_set])
x_test_zero = np.expand_dims(x_test_zero, axis=-1)
predictions_zero = model.predict(x_test_zero)

x_test_noise = np.asarray([perturb('noise',x,index_0,index_1) for x in perturb_test_set])
x_test_noise = np.expand_dims(x_test_noise, axis=-1)
predictions_noise = model.predict(x_test_noise)

x_test_blur = np.asarray([perturb('blur',x,index_0,index_1) for x in perturb_test_set])
x_test_blur = np.expand_dims(x_test_blur, axis=-1)
predictions_blur = model.predict(x_test_blur)
# Out:
# 12/12 [==============================] - 0s 6ms/step
# 12/12 [==============================] - 0s 6ms/step
# 12/12 [==============================] - 0s 8ms/step
# 12/12 [==============================] - 0s 8ms/step
# 12/12 [==============================] - 0s 6ms/step
# 12/12 [==============================] - 0s 6ms/step

# %%
def l2norm(perturb):
    # 计算两个数组之间的差
    difference = perturb - x_test_original
    
    # 计算差的平方
    squared_difference = np.square(difference)
    
    # 计算平方和，沿着特征维度（axis=1），因为每个时间序列样本是一行
    sum_of_squares = np.sum(squared_difference, axis=1)
    
    # 计算平方和的平方根，即l2范数
    l2_norms = np.sqrt(sum_of_squares)
    
    average_l2_norm = np.mean(l2_norms)
    
    # l2_norms现在是一个形状为(467,)的数组，其中每个元素代表
    # 对应时间序列样本之间的l2范数
    print(average_l2_norm)  # 输出: (467,)

l2norm(x_test_rbp)
l2norm(x_test_new1)
l2norm(x_test_zero)
l2norm(x_test_noise)
l2norm(x_test_blur)
# Out:
# 10.090239891687505
# 14.101657741798446
# 14.0698027802
# 22.901929649848352
# 3.325718333199836

# %%
def accuracy(predictions, labels):
    hits = 0
    for i in range(0,len(predictions)):
        if predictions[i] == labels[i]:
            hits += 1
    return hits/len(predictions)

# %%
original_accuracy = accuracy(np.argmax(predictions_original,axis=1), y_test_original)
rbp_accuracy = accuracy(np.argmax(predictions_rbp,axis=1), y_test_original)
new1_accuracy = accuracy(np.argmax(predictions_new1,axis=1), y_test_original)
#new2_accuracy = accuracy(np.argmax(predictions_new2,axis=1), y_test_original)
zero_accuracy = accuracy(np.argmax(predictions_zero,axis=1), y_test_original)
noise_accuracy = accuracy(np.argmax(predictions_noise,axis=1), y_test_original)
blur_accuracy = accuracy(np.argmax(predictions_blur,axis=1), y_test_original)

# %%
print(" Original Accuracy: " + str(original_accuracy) + "\n"+
    " RBP Accuracy: " + str(rbp_accuracy) + "\n"+
    " RBP1 Accuracy: " + str(new1_accuracy) + "\n"+
    #" RBP2 Accuracy: " + str(new2_accuracy) + "\n"+
      
    " Zero Accuracy: " + str(zero_accuracy) + "\n"+
    " Noise Accuracy: " + str(noise_accuracy) + "\n"+
    " Blur Accuracy: " + str(blur_accuracy) + "\n")
# Out:
#  Original Accuracy: 0.4826666666666667
#  RBP Accuracy: 0.496
#  RBP1 Accuracy: 0.432
#  Zero Accuracy: 0.43466666666666665
#  Noise Accuracy: 0.48533333333333334
#  Blur Accuracy: 0.5173333333333333

# %%
import numpy as np
import matplotlib.pyplot as plt
import inspect

# %%
import importlib
import sys
sys.path.append('../')
from Utils.perturbationsnew import RBPIndividual, RBPIndividualNew1, RBPIndividualNew1fast, RBPIndividualNew2, zeroPerturb, noisePerturb, blurPerturb,multisamplebackgroundIdentification
from Utils.models import *
from Utils.data import perturb, generateSynthetic, generateSyntheticPerturbReal,ReadTS

print(sys.path)
# Out:
# ['/Users/gali/anaconda3/envs/LIMEtf/lib/python310.zip', '/Users/gali/anaconda3/envs/LIMEtf/lib/python3.10', '/Users/gali/anaconda3/envs/LIMEtf/lib/python3.10/lib-dynload', '', '/Users/gali/anaconda3/envs/LIMEtf/lib/python3.10/site-packages', '/Users/gali/anaconda3/envs/LIMEtf/lib/python3.10/site-packages/setuptools/_vendor', '../', '../']

# %% [markdown]
# ## Test important content removal (accuracy decrease)

# %% [markdown]
# ### Load synthetic dataset and train CNN model

# %%
x_train, y_train,x_test_original, y_test_original = ReadTS('FordB')
#y_train = y_train - 1
#y_test_original = y_test_original - 1
y_train = np.where(y_train == -1, 0, y_train)
y_test_original = np.where(y_test_original == -1, 0, y_test_original)
print(x_train.shape)
print(y_train)
# Out:
# (3636, 500, 1)
# [1. 0. 0. ... 1. 1. 1.]

# %%
from sklearn.preprocessing import StandardScaler
def normalize(TS):
    # 获取原始数据集的形状
    original_shape = TS.shape
    
    # 将数据集reshape成二维数组
    TS_2d = TS.reshape(original_shape[0] , original_shape[1])
    
    # 初始化StandardScaler
    scaler = StandardScaler()
    
    # 对数据集进行标准化
    TS_normalized = scaler.fit_transform(TS_2d)
    
    # 将标准化后的数据集reshape回原始形状
    TS = TS_normalized.reshape(original_shape)
    
    return TS

x_train = normalize(x_train)
x_test_original = normalize(x_test_original)
#print(x_train)

# %%
model = make_CNN_model(x_train.shape[1:],num_classes = 2)
trained_model, history = train_CNN_model(model, x_train, y_train, epochs=200, batch_size=32)
# Out:
# Epoch 1/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.4500 - sparse_categorical_accuracy: 0.7995 - val_loss: 1.1284 - val_sparse_categorical_accuracy: 0.4904
# Epoch 2/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.3189 - sparse_categorical_accuracy: 0.8721 - val_loss: 1.3612 - val_sparse_categorical_accuracy: 0.4904
# Epoch 3/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.3224 - sparse_categorical_accuracy: 0.8645 - val_loss: 1.2418 - val_sparse_categorical_accuracy: 0.4904
# Epoch 4/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.3011 - sparse_categorical_accuracy: 0.8741 - val_loss: 0.8064 - val_sparse_categorical_accuracy: 0.4986
# Epoch 5/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2813 - sparse_categorical_accuracy: 0.8817 - val_loss: 0.5612 - val_sparse_categorical_accuracy: 0.6758
# Epoch 6/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2763 - sparse_categorical_accuracy: 0.8838 - val_loss: 0.4269 - val_sparse_categorical_accuracy: 0.7953
# Epoch 7/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2707 - sparse_categorical_accuracy: 0.8827 - val_loss: 0.7077 - val_sparse_categorical_accuracy: 0.6360
# Epoch 8/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2601 - sparse_categorical_accuracy: 0.8865 - val_loss: 0.4249 - val_sparse_categorical_accuracy: 0.7761
# Epoch 9/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2601 - sparse_categorical_accuracy: 0.8851 - val_loss: 0.5071 - val_sparse_categorical_accuracy: 0.7720
# Epoch 10/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2677 - sparse_categorical_accuracy: 0.8827 - val_loss: 0.4811 - val_sparse_categorical_accuracy: 0.7816
# Epoch 11/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2564 - sparse_categorical_accuracy: 0.8920 - val_loss: 0.5887 - val_sparse_categorical_accuracy: 0.7610
# Epoch 12/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2547 - sparse_categorical_accuracy: 0.8965 - val_loss: 0.3986 - val_sparse_categorical_accuracy: 0.8036
# Epoch 13/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2426 - sparse_categorical_accuracy: 0.8992 - val_loss: 0.3800 - val_sparse_categorical_accuracy: 0.8077
# Epoch 14/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2484 - sparse_categorical_accuracy: 0.8920 - val_loss: 0.4155 - val_sparse_categorical_accuracy: 0.8091
# Epoch 15/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2441 - sparse_categorical_accuracy: 0.8986 - val_loss: 0.3724 - val_sparse_categorical_accuracy: 0.8159
# Epoch 16/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2447 - sparse_categorical_accuracy: 0.8965 - val_loss: 0.6418 - val_sparse_categorical_accuracy: 0.7555
# Epoch 17/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2351 - sparse_categorical_accuracy: 0.9010 - val_loss: 0.5159 - val_sparse_categorical_accuracy: 0.7363
# Epoch 18/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2403 - sparse_categorical_accuracy: 0.8948 - val_loss: 0.6626 - val_sparse_categorical_accuracy: 0.6648
# Epoch 19/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2345 - sparse_categorical_accuracy: 0.9010 - val_loss: 0.6679 - val_sparse_categorical_accuracy: 0.6745
# Epoch 20/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2339 - sparse_categorical_accuracy: 0.9006 - val_loss: 0.3609 - val_sparse_categorical_accuracy: 0.8379
# Epoch 21/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2316 - sparse_categorical_accuracy: 0.8982 - val_loss: 0.3701 - val_sparse_categorical_accuracy: 0.8091
# Epoch 22/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2299 - sparse_categorical_accuracy: 0.9013 - val_loss: 0.5249 - val_sparse_categorical_accuracy: 0.7418
# Epoch 23/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.2220 - sparse_categorical_accuracy: 0.9085 - val_loss: 0.3739 - val_sparse_categorical_accuracy: 0.8255
# Epoch 24/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2280 - sparse_categorical_accuracy: 0.9068 - val_loss: 0.4376 - val_sparse_categorical_accuracy: 0.7995
# Epoch 25/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2188 - sparse_categorical_accuracy: 0.9075 - val_loss: 1.0172 - val_sparse_categorical_accuracy: 0.7047
# Epoch 26/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2129 - sparse_categorical_accuracy: 0.9133 - val_loss: 0.6985 - val_sparse_categorical_accuracy: 0.7404
# Epoch 27/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2226 - sparse_categorical_accuracy: 0.9068 - val_loss: 1.1791 - val_sparse_categorical_accuracy: 0.6676
# Epoch 28/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2136 - sparse_categorical_accuracy: 0.9106 - val_loss: 0.6457 - val_sparse_categorical_accuracy: 0.7088
# Epoch 29/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2167 - sparse_categorical_accuracy: 0.9116 - val_loss: 0.3525 - val_sparse_categorical_accuracy: 0.8242
# Epoch 30/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2061 - sparse_categorical_accuracy: 0.9144 - val_loss: 0.3920 - val_sparse_categorical_accuracy: 0.8077
# Epoch 31/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2179 - sparse_categorical_accuracy: 0.9089 - val_loss: 0.5866 - val_sparse_categorical_accuracy: 0.7102
# Epoch 32/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2045 - sparse_categorical_accuracy: 0.9147 - val_loss: 0.8562 - val_sparse_categorical_accuracy: 0.6566
# Epoch 33/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2041 - sparse_categorical_accuracy: 0.9123 - val_loss: 1.2110 - val_sparse_categorical_accuracy: 0.6497
# Epoch 34/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.2004 - sparse_categorical_accuracy: 0.9161 - val_loss: 0.6570 - val_sparse_categorical_accuracy: 0.7129
# Epoch 35/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1969 - sparse_categorical_accuracy: 0.9188 - val_loss: 0.7524 - val_sparse_categorical_accuracy: 0.6621
# Epoch 36/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1973 - sparse_categorical_accuracy: 0.9178 - val_loss: 0.4023 - val_sparse_categorical_accuracy: 0.8077
# Epoch 37/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1976 - sparse_categorical_accuracy: 0.9154 - val_loss: 0.3489 - val_sparse_categorical_accuracy: 0.8448
# Epoch 38/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1993 - sparse_categorical_accuracy: 0.9144 - val_loss: 0.7861 - val_sparse_categorical_accuracy: 0.6442
# Epoch 39/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2191 - sparse_categorical_accuracy: 0.9075 - val_loss: 1.8481 - val_sparse_categorical_accuracy: 0.5192
# Epoch 40/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2124 - sparse_categorical_accuracy: 0.9154 - val_loss: 0.5407 - val_sparse_categorical_accuracy: 0.7321
# Epoch 41/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2076 - sparse_categorical_accuracy: 0.9192 - val_loss: 0.7565 - val_sparse_categorical_accuracy: 0.7473
# Epoch 42/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.2023 - sparse_categorical_accuracy: 0.9199 - val_loss: 0.5603 - val_sparse_categorical_accuracy: 0.7912
# Epoch 43/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1951 - sparse_categorical_accuracy: 0.9226 - val_loss: 0.8159 - val_sparse_categorical_accuracy: 0.6731
# Epoch 44/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1834 - sparse_categorical_accuracy: 0.9254 - val_loss: 0.6562 - val_sparse_categorical_accuracy: 0.7170
# Epoch 45/200
# 91/91 [==============================] - 2s 25ms/step - loss: 0.1889 - sparse_categorical_accuracy: 0.9278 - val_loss: 0.7191 - val_sparse_categorical_accuracy: 0.6923
# Epoch 46/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1889 - sparse_categorical_accuracy: 0.9237 - val_loss: 0.4938 - val_sparse_categorical_accuracy: 0.7775
# Epoch 47/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1922 - sparse_categorical_accuracy: 0.9185 - val_loss: 0.8086 - val_sparse_categorical_accuracy: 0.6607
# Epoch 48/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1838 - sparse_categorical_accuracy: 0.9230 - val_loss: 0.3744 - val_sparse_categorical_accuracy: 0.8352
# Epoch 49/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1878 - sparse_categorical_accuracy: 0.9257 - val_loss: 0.3204 - val_sparse_categorical_accuracy: 0.8613
# Epoch 50/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1825 - sparse_categorical_accuracy: 0.9240 - val_loss: 0.3163 - val_sparse_categorical_accuracy: 0.8750
# Epoch 51/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.1838 - sparse_categorical_accuracy: 0.9233 - val_loss: 0.4178 - val_sparse_categorical_accuracy: 0.8132
# Epoch 52/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.1762 - sparse_categorical_accuracy: 0.9295 - val_loss: 0.3637 - val_sparse_categorical_accuracy: 0.8393
# Epoch 53/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.1775 - sparse_categorical_accuracy: 0.9295 - val_loss: 0.9571 - val_sparse_categorical_accuracy: 0.6209
# Epoch 54/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.1759 - sparse_categorical_accuracy: 0.9357 - val_loss: 0.4512 - val_sparse_categorical_accuracy: 0.7912
# Epoch 55/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1816 - sparse_categorical_accuracy: 0.9254 - val_loss: 1.0603 - val_sparse_categorical_accuracy: 0.7074
# Epoch 56/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1750 - sparse_categorical_accuracy: 0.9288 - val_loss: 0.9913 - val_sparse_categorical_accuracy: 0.7033
# Epoch 57/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.1737 - sparse_categorical_accuracy: 0.9323 - val_loss: 0.3673 - val_sparse_categorical_accuracy: 0.8242
# Epoch 58/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.1710 - sparse_categorical_accuracy: 0.9271 - val_loss: 0.4495 - val_sparse_categorical_accuracy: 0.7816
# Epoch 59/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1751 - sparse_categorical_accuracy: 0.9302 - val_loss: 0.3161 - val_sparse_categorical_accuracy: 0.8613
# Epoch 60/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1715 - sparse_categorical_accuracy: 0.9305 - val_loss: 0.3666 - val_sparse_categorical_accuracy: 0.8255
# Epoch 61/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1665 - sparse_categorical_accuracy: 0.9350 - val_loss: 1.0970 - val_sparse_categorical_accuracy: 0.7047
# Epoch 62/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1784 - sparse_categorical_accuracy: 0.9274 - val_loss: 0.3204 - val_sparse_categorical_accuracy: 0.8613
# Epoch 63/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1614 - sparse_categorical_accuracy: 0.9354 - val_loss: 0.3304 - val_sparse_categorical_accuracy: 0.8407
# Epoch 64/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1727 - sparse_categorical_accuracy: 0.9319 - val_loss: 0.4791 - val_sparse_categorical_accuracy: 0.7953
# Epoch 65/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1589 - sparse_categorical_accuracy: 0.9419 - val_loss: 0.3340 - val_sparse_categorical_accuracy: 0.8613
# Epoch 66/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1607 - sparse_categorical_accuracy: 0.9402 - val_loss: 0.4910 - val_sparse_categorical_accuracy: 0.7734
# Epoch 67/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1660 - sparse_categorical_accuracy: 0.9381 - val_loss: 0.4454 - val_sparse_categorical_accuracy: 0.8077
# Epoch 68/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1648 - sparse_categorical_accuracy: 0.9357 - val_loss: 0.8055 - val_sparse_categorical_accuracy: 0.6525
# Epoch 69/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1529 - sparse_categorical_accuracy: 0.9395 - val_loss: 0.4398 - val_sparse_categorical_accuracy: 0.8049
# Epoch 70/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1587 - sparse_categorical_accuracy: 0.9402 - val_loss: 0.3151 - val_sparse_categorical_accuracy: 0.8832
# Epoch 71/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1575 - sparse_categorical_accuracy: 0.9395 - val_loss: 0.5258 - val_sparse_categorical_accuracy: 0.7706
# Epoch 72/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1514 - sparse_categorical_accuracy: 0.9422 - val_loss: 0.5540 - val_sparse_categorical_accuracy: 0.7527
# Epoch 73/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1564 - sparse_categorical_accuracy: 0.9378 - val_loss: 0.3608 - val_sparse_categorical_accuracy: 0.8393
# Epoch 74/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1605 - sparse_categorical_accuracy: 0.9357 - val_loss: 0.8862 - val_sparse_categorical_accuracy: 0.7486
# Epoch 75/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1640 - sparse_categorical_accuracy: 0.9354 - val_loss: 0.3395 - val_sparse_categorical_accuracy: 0.8420
# Epoch 76/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1539 - sparse_categorical_accuracy: 0.9439 - val_loss: 0.5310 - val_sparse_categorical_accuracy: 0.7720
# Epoch 77/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1562 - sparse_categorical_accuracy: 0.9381 - val_loss: 0.6179 - val_sparse_categorical_accuracy: 0.7088
# Epoch 78/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1598 - sparse_categorical_accuracy: 0.9333 - val_loss: 0.4040 - val_sparse_categorical_accuracy: 0.8063
# Epoch 79/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1598 - sparse_categorical_accuracy: 0.9360 - val_loss: 0.9522 - val_sparse_categorical_accuracy: 0.7184
# Epoch 80/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1547 - sparse_categorical_accuracy: 0.9384 - val_loss: 1.3659 - val_sparse_categorical_accuracy: 0.6964
# Epoch 81/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1555 - sparse_categorical_accuracy: 0.9405 - val_loss: 2.1780 - val_sparse_categorical_accuracy: 0.6786
# Epoch 82/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1578 - sparse_categorical_accuracy: 0.9395 - val_loss: 0.3480 - val_sparse_categorical_accuracy: 0.8558
# Epoch 83/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1495 - sparse_categorical_accuracy: 0.9460 - val_loss: 0.7234 - val_sparse_categorical_accuracy: 0.6827
# Epoch 84/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1508 - sparse_categorical_accuracy: 0.9388 - val_loss: 0.5668 - val_sparse_categorical_accuracy: 0.7651
# Epoch 85/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1580 - sparse_categorical_accuracy: 0.9374 - val_loss: 0.7766 - val_sparse_categorical_accuracy: 0.7184
# Epoch 86/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1523 - sparse_categorical_accuracy: 0.9402 - val_loss: 0.7810 - val_sparse_categorical_accuracy: 0.7225
# Epoch 87/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1497 - sparse_categorical_accuracy: 0.9371 - val_loss: 0.5593 - val_sparse_categorical_accuracy: 0.7596
# Epoch 88/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1511 - sparse_categorical_accuracy: 0.9422 - val_loss: 0.4495 - val_sparse_categorical_accuracy: 0.7885
# Epoch 89/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1423 - sparse_categorical_accuracy: 0.9508 - val_loss: 0.3077 - val_sparse_categorical_accuracy: 0.8860
# Epoch 90/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1503 - sparse_categorical_accuracy: 0.9426 - val_loss: 0.3231 - val_sparse_categorical_accuracy: 0.8640
# Epoch 91/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1524 - sparse_categorical_accuracy: 0.9381 - val_loss: 1.4460 - val_sparse_categorical_accuracy: 0.6497
# Epoch 92/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1504 - sparse_categorical_accuracy: 0.9391 - val_loss: 0.3749 - val_sparse_categorical_accuracy: 0.8516
# Epoch 93/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1491 - sparse_categorical_accuracy: 0.9412 - val_loss: 0.6848 - val_sparse_categorical_accuracy: 0.7129
# Epoch 94/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1419 - sparse_categorical_accuracy: 0.9470 - val_loss: 0.4352 - val_sparse_categorical_accuracy: 0.8269
# Epoch 95/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1495 - sparse_categorical_accuracy: 0.9453 - val_loss: 1.3508 - val_sparse_categorical_accuracy: 0.7143
# Epoch 96/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1486 - sparse_categorical_accuracy: 0.9426 - val_loss: 2.7818 - val_sparse_categorical_accuracy: 0.6085
# Epoch 97/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1467 - sparse_categorical_accuracy: 0.9419 - val_loss: 0.3079 - val_sparse_categorical_accuracy: 0.8901
# Epoch 98/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1530 - sparse_categorical_accuracy: 0.9367 - val_loss: 0.5334 - val_sparse_categorical_accuracy: 0.7582
# Epoch 99/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1428 - sparse_categorical_accuracy: 0.9457 - val_loss: 0.9237 - val_sparse_categorical_accuracy: 0.6456
# Epoch 100/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1467 - sparse_categorical_accuracy: 0.9457 - val_loss: 1.0387 - val_sparse_categorical_accuracy: 0.6593
# Epoch 101/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1488 - sparse_categorical_accuracy: 0.9384 - val_loss: 0.3284 - val_sparse_categorical_accuracy: 0.8736
# Epoch 102/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1434 - sparse_categorical_accuracy: 0.9436 - val_loss: 0.3195 - val_sparse_categorical_accuracy: 0.8805
# Epoch 103/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1458 - sparse_categorical_accuracy: 0.9381 - val_loss: 0.3529 - val_sparse_categorical_accuracy: 0.8530
# Epoch 104/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1478 - sparse_categorical_accuracy: 0.9429 - val_loss: 0.3706 - val_sparse_categorical_accuracy: 0.8503
# Epoch 105/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1482 - sparse_categorical_accuracy: 0.9433 - val_loss: 0.4763 - val_sparse_categorical_accuracy: 0.8022
# Epoch 106/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1447 - sparse_categorical_accuracy: 0.9464 - val_loss: 0.5209 - val_sparse_categorical_accuracy: 0.8159
# Epoch 107/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1451 - sparse_categorical_accuracy: 0.9419 - val_loss: 0.8500 - val_sparse_categorical_accuracy: 0.7321
# Epoch 108/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1480 - sparse_categorical_accuracy: 0.9398 - val_loss: 0.4988 - val_sparse_categorical_accuracy: 0.7802
# Epoch 109/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1432 - sparse_categorical_accuracy: 0.9439 - val_loss: 0.7064 - val_sparse_categorical_accuracy: 0.7445
# Epoch 110/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1449 - sparse_categorical_accuracy: 0.9388 - val_loss: 0.4498 - val_sparse_categorical_accuracy: 0.8173
# Epoch 111/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1461 - sparse_categorical_accuracy: 0.9460 - val_loss: 0.9101 - val_sparse_categorical_accuracy: 0.7376
# Epoch 112/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1394 - sparse_categorical_accuracy: 0.9457 - val_loss: 1.1865 - val_sparse_categorical_accuracy: 0.7212
# Epoch 113/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1453 - sparse_categorical_accuracy: 0.9409 - val_loss: 0.3123 - val_sparse_categorical_accuracy: 0.8819
# Epoch 114/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1416 - sparse_categorical_accuracy: 0.9464 - val_loss: 0.3270 - val_sparse_categorical_accuracy: 0.8723
# Epoch 115/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1430 - sparse_categorical_accuracy: 0.9457 - val_loss: 0.4012 - val_sparse_categorical_accuracy: 0.8448
# Epoch 116/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1441 - sparse_categorical_accuracy: 0.9484 - val_loss: 0.4256 - val_sparse_categorical_accuracy: 0.8173
# Epoch 117/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1462 - sparse_categorical_accuracy: 0.9433 - val_loss: 0.8126 - val_sparse_categorical_accuracy: 0.6772
# Epoch 118/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1400 - sparse_categorical_accuracy: 0.9470 - val_loss: 0.3635 - val_sparse_categorical_accuracy: 0.8503
# Epoch 119/200
# 91/91 [==============================] - 2s 25ms/step - loss: 0.1491 - sparse_categorical_accuracy: 0.9436 - val_loss: 1.3259 - val_sparse_categorical_accuracy: 0.7225
# Epoch 120/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1409 - sparse_categorical_accuracy: 0.9453 - val_loss: 1.9806 - val_sparse_categorical_accuracy: 0.6758
# Epoch 121/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1453 - sparse_categorical_accuracy: 0.9415 - val_loss: 0.3160 - val_sparse_categorical_accuracy: 0.8777
# Epoch 122/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1416 - sparse_categorical_accuracy: 0.9412 - val_loss: 0.5083 - val_sparse_categorical_accuracy: 0.8077
# Epoch 123/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1387 - sparse_categorical_accuracy: 0.9464 - val_loss: 0.3971 - val_sparse_categorical_accuracy: 0.8407
# Epoch 124/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1389 - sparse_categorical_accuracy: 0.9508 - val_loss: 0.6302 - val_sparse_categorical_accuracy: 0.7500
# Epoch 125/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1361 - sparse_categorical_accuracy: 0.9467 - val_loss: 0.3123 - val_sparse_categorical_accuracy: 0.8874
# Epoch 126/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1342 - sparse_categorical_accuracy: 0.9508 - val_loss: 0.7567 - val_sparse_categorical_accuracy: 0.7170
# Epoch 127/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1411 - sparse_categorical_accuracy: 0.9409 - val_loss: 0.7491 - val_sparse_categorical_accuracy: 0.7363
# Epoch 128/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1425 - sparse_categorical_accuracy: 0.9450 - val_loss: 0.4094 - val_sparse_categorical_accuracy: 0.8338
# Epoch 129/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1314 - sparse_categorical_accuracy: 0.9467 - val_loss: 0.9346 - val_sparse_categorical_accuracy: 0.6305
# Epoch 130/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1411 - sparse_categorical_accuracy: 0.9460 - val_loss: 0.9771 - val_sparse_categorical_accuracy: 0.6525
# Epoch 131/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1396 - sparse_categorical_accuracy: 0.9491 - val_loss: 0.4264 - val_sparse_categorical_accuracy: 0.8516
# Epoch 132/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1420 - sparse_categorical_accuracy: 0.9436 - val_loss: 0.3918 - val_sparse_categorical_accuracy: 0.8393
# Epoch 133/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1409 - sparse_categorical_accuracy: 0.9450 - val_loss: 0.3207 - val_sparse_categorical_accuracy: 0.8805
# Epoch 134/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1324 - sparse_categorical_accuracy: 0.9460 - val_loss: 0.3280 - val_sparse_categorical_accuracy: 0.8791
# Epoch 135/200
# 91/91 [==============================] - 2s 25ms/step - loss: 0.1415 - sparse_categorical_accuracy: 0.9464 - val_loss: 0.6703 - val_sparse_categorical_accuracy: 0.7349
# Epoch 136/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1425 - sparse_categorical_accuracy: 0.9457 - val_loss: 0.3361 - val_sparse_categorical_accuracy: 0.8777
# Epoch 137/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1326 - sparse_categorical_accuracy: 0.9505 - val_loss: 0.4910 - val_sparse_categorical_accuracy: 0.8269
# Epoch 138/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1331 - sparse_categorical_accuracy: 0.9515 - val_loss: 0.4921 - val_sparse_categorical_accuracy: 0.8146
# Epoch 139/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1360 - sparse_categorical_accuracy: 0.9477 - val_loss: 0.8002 - val_sparse_categorical_accuracy: 0.6923
# Epoch 140/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1351 - sparse_categorical_accuracy: 0.9460 - val_loss: 0.4822 - val_sparse_categorical_accuracy: 0.8255
# Epoch 141/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1347 - sparse_categorical_accuracy: 0.9470 - val_loss: 0.3855 - val_sparse_categorical_accuracy: 0.8558
# Epoch 142/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1252 - sparse_categorical_accuracy: 0.9556 - val_loss: 0.4680 - val_sparse_categorical_accuracy: 0.8214
# Epoch 143/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1318 - sparse_categorical_accuracy: 0.9484 - val_loss: 2.1812 - val_sparse_categorical_accuracy: 0.5879
# Epoch 144/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1329 - sparse_categorical_accuracy: 0.9464 - val_loss: 0.3637 - val_sparse_categorical_accuracy: 0.8420
# Epoch 145/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1322 - sparse_categorical_accuracy: 0.9529 - val_loss: 0.3494 - val_sparse_categorical_accuracy: 0.8585
# Epoch 146/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1408 - sparse_categorical_accuracy: 0.9439 - val_loss: 0.4875 - val_sparse_categorical_accuracy: 0.8049
# Epoch 147/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1333 - sparse_categorical_accuracy: 0.9467 - val_loss: 0.4439 - val_sparse_categorical_accuracy: 0.8269
# Epoch 148/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1374 - sparse_categorical_accuracy: 0.9467 - val_loss: 0.8880 - val_sparse_categorical_accuracy: 0.6964
# Epoch 149/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.1361 - sparse_categorical_accuracy: 0.9477 - val_loss: 0.3224 - val_sparse_categorical_accuracy: 0.8819
# Epoch 150/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1346 - sparse_categorical_accuracy: 0.9477 - val_loss: 0.3567 - val_sparse_categorical_accuracy: 0.8626
# Epoch 151/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1390 - sparse_categorical_accuracy: 0.9477 - val_loss: 0.3367 - val_sparse_categorical_accuracy: 0.8805
# Epoch 152/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1399 - sparse_categorical_accuracy: 0.9450 - val_loss: 0.6226 - val_sparse_categorical_accuracy: 0.7637
# Epoch 153/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.1273 - sparse_categorical_accuracy: 0.9515 - val_loss: 0.3684 - val_sparse_categorical_accuracy: 0.8613
# Epoch 154/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1307 - sparse_categorical_accuracy: 0.9512 - val_loss: 0.5279 - val_sparse_categorical_accuracy: 0.7940
# Epoch 155/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1287 - sparse_categorical_accuracy: 0.9501 - val_loss: 0.6416 - val_sparse_categorical_accuracy: 0.7610
# Epoch 156/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1349 - sparse_categorical_accuracy: 0.9477 - val_loss: 0.3620 - val_sparse_categorical_accuracy: 0.8695
# Epoch 157/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1312 - sparse_categorical_accuracy: 0.9539 - val_loss: 0.5750 - val_sparse_categorical_accuracy: 0.7637
# Epoch 158/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1349 - sparse_categorical_accuracy: 0.9467 - val_loss: 0.4718 - val_sparse_categorical_accuracy: 0.8255
# Epoch 159/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1327 - sparse_categorical_accuracy: 0.9525 - val_loss: 0.3636 - val_sparse_categorical_accuracy: 0.8544
# Epoch 160/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1295 - sparse_categorical_accuracy: 0.9522 - val_loss: 0.4666 - val_sparse_categorical_accuracy: 0.8297
# Epoch 161/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1304 - sparse_categorical_accuracy: 0.9515 - val_loss: 0.3349 - val_sparse_categorical_accuracy: 0.8819
# Epoch 162/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1273 - sparse_categorical_accuracy: 0.9508 - val_loss: 0.3520 - val_sparse_categorical_accuracy: 0.8723
# Epoch 163/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1285 - sparse_categorical_accuracy: 0.9505 - val_loss: 0.7777 - val_sparse_categorical_accuracy: 0.6951
# Epoch 164/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1344 - sparse_categorical_accuracy: 0.9467 - val_loss: 0.3630 - val_sparse_categorical_accuracy: 0.8530
# Epoch 165/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1303 - sparse_categorical_accuracy: 0.9515 - val_loss: 1.2106 - val_sparse_categorical_accuracy: 0.7157
# Epoch 166/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1329 - sparse_categorical_accuracy: 0.9515 - val_loss: 0.5887 - val_sparse_categorical_accuracy: 0.7830
# Epoch 167/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1291 - sparse_categorical_accuracy: 0.9474 - val_loss: 0.4333 - val_sparse_categorical_accuracy: 0.8365
# Epoch 168/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1348 - sparse_categorical_accuracy: 0.9515 - val_loss: 0.3272 - val_sparse_categorical_accuracy: 0.8764
# Epoch 169/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1243 - sparse_categorical_accuracy: 0.9543 - val_loss: 0.6948 - val_sparse_categorical_accuracy: 0.7431
# Epoch 170/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1293 - sparse_categorical_accuracy: 0.9491 - val_loss: 1.0944 - val_sparse_categorical_accuracy: 0.6937
# Epoch 171/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1211 - sparse_categorical_accuracy: 0.9570 - val_loss: 0.4765 - val_sparse_categorical_accuracy: 0.8242
# Epoch 172/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1283 - sparse_categorical_accuracy: 0.9546 - val_loss: 0.3629 - val_sparse_categorical_accuracy: 0.8709
# Epoch 173/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1323 - sparse_categorical_accuracy: 0.9508 - val_loss: 1.5205 - val_sparse_categorical_accuracy: 0.6813
# Epoch 174/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1271 - sparse_categorical_accuracy: 0.9522 - val_loss: 1.4036 - val_sparse_categorical_accuracy: 0.6882
# Epoch 175/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1321 - sparse_categorical_accuracy: 0.9488 - val_loss: 2.7513 - val_sparse_categorical_accuracy: 0.5577
# Epoch 176/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1349 - sparse_categorical_accuracy: 0.9481 - val_loss: 1.1593 - val_sparse_categorical_accuracy: 0.7266
# Epoch 177/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1293 - sparse_categorical_accuracy: 0.9529 - val_loss: 0.3429 - val_sparse_categorical_accuracy: 0.8709
# Epoch 178/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1262 - sparse_categorical_accuracy: 0.9529 - val_loss: 0.7287 - val_sparse_categorical_accuracy: 0.7363
# Epoch 179/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1219 - sparse_categorical_accuracy: 0.9525 - val_loss: 0.3319 - val_sparse_categorical_accuracy: 0.8764
# Epoch 180/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1241 - sparse_categorical_accuracy: 0.9577 - val_loss: 0.6041 - val_sparse_categorical_accuracy: 0.7692
# Epoch 181/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1264 - sparse_categorical_accuracy: 0.9512 - val_loss: 0.8392 - val_sparse_categorical_accuracy: 0.7404
# Epoch 182/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1245 - sparse_categorical_accuracy: 0.9543 - val_loss: 0.3787 - val_sparse_categorical_accuracy: 0.8640
# Epoch 183/200
# 91/91 [==============================] - 2s 22ms/step - loss: 0.1263 - sparse_categorical_accuracy: 0.9508 - val_loss: 0.4517 - val_sparse_categorical_accuracy: 0.8352
# Epoch 184/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1270 - sparse_categorical_accuracy: 0.9525 - val_loss: 0.7536 - val_sparse_categorical_accuracy: 0.7431
# Epoch 185/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1285 - sparse_categorical_accuracy: 0.9508 - val_loss: 0.3312 - val_sparse_categorical_accuracy: 0.8723
# Epoch 186/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1258 - sparse_categorical_accuracy: 0.9508 - val_loss: 0.4590 - val_sparse_categorical_accuracy: 0.8283
# Epoch 187/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1193 - sparse_categorical_accuracy: 0.9556 - val_loss: 0.4547 - val_sparse_categorical_accuracy: 0.8146
# Epoch 188/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1222 - sparse_categorical_accuracy: 0.9539 - val_loss: 0.9625 - val_sparse_categorical_accuracy: 0.7033
# Epoch 189/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1291 - sparse_categorical_accuracy: 0.9501 - val_loss: 0.3299 - val_sparse_categorical_accuracy: 0.8942
# Epoch 190/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1240 - sparse_categorical_accuracy: 0.9519 - val_loss: 0.3959 - val_sparse_categorical_accuracy: 0.8420
# Epoch 191/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1185 - sparse_categorical_accuracy: 0.9543 - val_loss: 0.4599 - val_sparse_categorical_accuracy: 0.8379
# Epoch 192/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1279 - sparse_categorical_accuracy: 0.9488 - val_loss: 0.5113 - val_sparse_categorical_accuracy: 0.7912
# Epoch 193/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1239 - sparse_categorical_accuracy: 0.9536 - val_loss: 1.6679 - val_sparse_categorical_accuracy: 0.6745
# Epoch 194/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1220 - sparse_categorical_accuracy: 0.9546 - val_loss: 0.4430 - val_sparse_categorical_accuracy: 0.8255
# Epoch 195/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1241 - sparse_categorical_accuracy: 0.9494 - val_loss: 0.4465 - val_sparse_categorical_accuracy: 0.8201
# Epoch 196/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1196 - sparse_categorical_accuracy: 0.9553 - val_loss: 0.3513 - val_sparse_categorical_accuracy: 0.8750
# Epoch 197/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1280 - sparse_categorical_accuracy: 0.9519 - val_loss: 0.3651 - val_sparse_categorical_accuracy: 0.8668
# Epoch 198/200
# 91/91 [==============================] - 2s 23ms/step - loss: 0.1210 - sparse_categorical_accuracy: 0.9512 - val_loss: 0.4574 - val_sparse_categorical_accuracy: 0.8228
# Epoch 199/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1189 - sparse_categorical_accuracy: 0.9556 - val_loss: 0.7431 - val_sparse_categorical_accuracy: 0.7473
# Epoch 200/200
# 91/91 [==============================] - 2s 24ms/step - loss: 0.1364 - sparse_categorical_accuracy: 0.9467 - val_loss: 0.3635 - val_sparse_categorical_accuracy: 0.8585

# %%
test_loss, test_acc = trained_model.evaluate(x_test_original, y_test_original)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5717 - sparse_categorical_accuracy: 0.7568
# Test accuracy 0.7567901015281677
# Test loss 0.5717039704322815

# %% [markdown]
# ### Create perturbed test sets and calculate decrease in accuracy

# %%
print(y_test_original.shape)
# Out:
# (810,)

# %%
print(inspect.getsource(perturb))
print(inspect.signature(perturb))
# Out:
# def perturb(perturbation_strategy, ts, index0, index1, global_ts = [],bg = []):
#     if perturbation_strategy == 'RBP':
#         return RBPIndividual(ts, index0, index1)
#     if perturbation_strategy == 'zero':
#         return zeroPerturb(ts, index0, index1)
#     if perturbation_strategy == 'noise':
#         return noisePerturb(ts, index0, index1)
#     if perturbation_strategy == 'blur':
#         return blurPerturb(ts, index0, index1)
#     if perturbation_strategy == 'RBP1':
#         return RBPIndividualNew1(global_ts, ts, index0, index1)
#     if perturbation_strategy == 'RBP1fast':
#         return RBPIndividualNew1fast(bg, ts, index0, index1)
#     if perturbation_strategy == 'RBP2':
#         return RBPIndividualNew2(global_ts, ts, index0, index1)
#
# (perturbation_strategy, ts, index0, index1, global_ts=[], bg=[])

# %%
predictions_original = model.predict(x_test_original)
perturb_test_set = x_test_original.copy()
perturb_test_set = perturb_test_set.reshape(x_test_original.shape[0:2])
index_0 = 0
index_1 = 200
x_test_rbp = np.asarray([perturb('RBP',x,index_0,index_1) for x in perturb_test_set])
x_test_rbp = np.expand_dims(x_test_rbp, axis=-1)
predictions_rbp = model.predict(x_test_rbp)

bg = multisamplebackgroundIdentification(perturb_test_set)
x_test_new1 = np.asarray([perturb('RBP1fast',x,index_0,index_1, bg = bg) for x in perturb_test_set])
x_test_new1 = np.expand_dims(x_test_new1, axis=-1)
predictions_new1 = model.predict(x_test_new1)

#x_test_new2 = np.asarray([perturb('RBP2',x,400,500, global_ts = perturb_test_set) for x in perturb_test_set])
#x_test_new2 = np.expand_dims(x_test_new2, axis=-1)
#predictions_new2 = model.predict(x_test_new2)

x_test_zero = np.asarray([perturb('zero',x,index_0,index_1) for x in perturb_test_set])
x_test_zero = np.expand_dims(x_test_zero, axis=-1)
predictions_zero = model.predict(x_test_zero)

x_test_noise = np.asarray([perturb('noise',x,index_0,index_1) for x in perturb_test_set])
x_test_noise = np.expand_dims(x_test_noise, axis=-1)
predictions_noise = model.predict(x_test_noise)

x_test_blur = np.asarray([perturb('blur',x,index_0,index_1) for x in perturb_test_set])
x_test_blur = np.expand_dims(x_test_blur, axis=-1)
predictions_blur = model.predict(x_test_blur)
# Out:
# 26/26 [==============================] - 0s 4ms/step
# 26/26 [==============================] - 0s 4ms/step
# 26/26 [==============================] - 0s 4ms/step
# 26/26 [==============================] - 0s 4ms/step
# 26/26 [==============================] - 0s 4ms/step
# 26/26 [==============================] - 0s 4ms/step

# %%
def l2norm(perturb):
    # 计算两个数组之间的差
    difference = perturb - x_test_original
    
    # 计算差的平方
    squared_difference = np.square(difference)
    
    # 计算平方和，沿着特征维度（axis=1），因为每个时间序列样本是一行
    sum_of_squares = np.sum(squared_difference, axis=1)
    
    # 计算平方和的平方根，即l2范数
    l2_norms = np.sqrt(sum_of_squares)
    
    average_l2_norm = np.mean(l2_norms)
    
    # l2_norms现在是一个形状为(467,)的数组，其中每个元素代表
    # 对应时间序列样本之间的l2范数
    print(average_l2_norm)  # 输出: (467,)

l2norm(x_test_rbp)
l2norm(x_test_new1)
l2norm(x_test_zero)
l2norm(x_test_noise)
l2norm(x_test_blur)
# Out:
# 11.352376257588949
# 14.066043437516148
# 13.785469016047761
# 26.493070025195742
# 0.719994920476665

# %%
def accuracy(predictions, labels):
    hits = 0
    for i in range(0,len(predictions)):
        if predictions[i] == labels[i]:
            hits += 1
    return hits/len(predictions)

# %%
original_accuracy = accuracy(np.argmax(predictions_original,axis=1), y_test_original)
rbp_accuracy = accuracy(np.argmax(predictions_rbp,axis=1), y_test_original)
new1_accuracy = accuracy(np.argmax(predictions_new1,axis=1), y_test_original)
#new2_accuracy = accuracy(np.argmax(predictions_new2,axis=1), y_test_original)
zero_accuracy = accuracy(np.argmax(predictions_zero,axis=1), y_test_original)
noise_accuracy = accuracy(np.argmax(predictions_noise,axis=1), y_test_original)
blur_accuracy = accuracy(np.argmax(predictions_blur,axis=1), y_test_original)

# %%
print(" Original Accuracy: " + str(original_accuracy) + "\n"+
    " RBP Accuracy: " + str(rbp_accuracy) + "\n"+
    " RBP1 Accuracy: " + str(new1_accuracy) + "\n"+
    #" RBP2 Accuracy: " + str(new2_accuracy) + "\n"+
      
    " Zero Accuracy: " + str(zero_accuracy) + "\n"+
    " Noise Accuracy: " + str(noise_accuracy) + "\n"+
    " Blur Accuracy: " + str(blur_accuracy) + "\n")
# Out:
#  Original Accuracy: 0.7567901234567901
#  RBP Accuracy: 0.6962962962962963
#  RBP1 Accuracy: 0.5172839506172839
#  Zero Accuracy: 0.6580246913580247
#  Noise Accuracy: 0.49506172839506174
#  Blur Accuracy: 0.7493827160493827
